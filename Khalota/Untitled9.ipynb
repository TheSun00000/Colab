# %%
import matplotlib.pyplot as plt

# %%
import io
import os
import random
import base64
import json
# from flask import Flask, jsonify, request, render_template, session
# from flask_kvsession import KVSessionExtension
import numpy as np

# from sqlalchemy import create_engine, MetaData
# from simplekv.db.sql import SQLAlchemyStore
from datetime import timedelta

# from werkzeug.utils import secure_filename
# from werkzeug.exceptions import HTTPException
from PIL import Image
import imagehash

from torchvision import models
import torchvision.transforms as transforms
import torchvision 
import torch.nn as nn
import torch




# ------------------ Model goes here ⬇------------------ #
imagenet_class_index = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model_nonrobust = models.resnet18()
num_ftrs = model_nonrobust.fc.in_features
model_nonrobust.fc = nn.Linear(num_ftrs, len(imagenet_class_index))
model_nonrobust.load_state_dict(torch.load("./models/pwny_cifar_eps_0.pth", map_location = device))
model_ft = model_nonrobust.to(device)
model_nonrobust.eval()

model_robust = models.resnet18()
num_ftrs = model_robust.fc.in_features
model_robust.fc = nn.Linear(num_ftrs, len(imagenet_class_index))
model_robust.load_state_dict(torch.load("./models/pwny_cifar_eps_0.5.pth", map_location = device))
model_ft = model_robust.to(device)
model_robust.eval()

image_set = torchvision.datasets.CIFAR10(root='static/images', train=False, download=True)
# ------------------ Model goes here ------------------ #

# Get a random image and show it to the user
def gen_img():
    label = 0
    while label != 7:
        curr_image, label = image_set[random.randint(1, len(image_set))]

    resize_images = transforms.Compose([transforms.Resize(256),
                        transforms.CenterCrop(224)])
    curr_image = resize_images(curr_image)

    buffered = io.BytesIO()
    curr_image.save(buffered, format='png')
    return base64.b64encode(buffered.getvalue()).decode('utf-8')

# Transform image to normalize into model's bounds
def transform_image(image_bytes):
    my_transforms = transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize(
                            [0.485, 0.456, 0.406],
                            [0.229, 0.224, 0.225])])
    image = Image.open(io.BytesIO(image_bytes))
    return my_transforms(image).unsqueeze(0)


def tensor_to_image(tensor):
    tensor = tensor.detach().squeeze().numpy()
    tensor = tensor.transpose(1, 2, 0)
    tensor = (tensor * 255).astype(np.uint8)
    return Image.fromarray(tensor)

def image_to_tensor(img):
    tensor = np.array(img).astype(np.float32) / 255.0
    # HWC -> CHW
    tensor = tensor.transpose(2, 0, 1)
    tensor = tensor[None, :, :, :]  # add batch dimension
    return torch.tensor(tensor, requires_grad=True)

def bytes_to_image(img_data):
    import tempfile
    with tempfile.NamedTemporaryFile(suffix='.png') as tmp:
        tmp.write(img_data)
        tmp.flush()
        return Image.open(tmp.name)

def unused_get_prediction(image_bytes, model, curr_image = None):
    input_img = bytes_to_image(image_bytes)
    input_img_tensor = image_to_tensor(input_img)

    original_img = Image.open(io.BytesIO(base64.b64decode(curr_image)))
    orig_img_tensor = image_to_tensor(original_img)

    outputs = model(input_img_tensor)
    preds = torch.argmax(outputs, 1)

    # how much they are allowed to change the image
    # threshold: float from 0 to 1?
    # TODO: TUNE ME
    # range of possible values is 0 - 3072 (3072 = 32 * 32 * 3)
    # we probably want 5-15% different. x / 3072
    if ((orig_img_tensor - input_img_tensor)**2).sum() < 500:
        return imagenet_class_index[preds]
    else:
        return "IMAGE WAS TOO DIFFERENT"

# Use imagehash to compare relative closeness of image (can't just allow random images to be thrown at the model...)
def get_prediction(image_bytes, model, curr_image = None):
    inputs = transform_image(image_bytes=image_bytes)
    outputs = model(inputs)
    preds = torch.argmax(outputs, 1)
    original = Image.open(io.BytesIO(base64.b64decode(curr_image)))

    # "where the magic happens" - akshunna
    input_image = Image.open(io.BytesIO(image_bytes))
    hash_orig = imagehash.average_hash(original)
    hash_input = imagehash.average_hash(input_image)

        # currently HASH_DIFFERENCE is 5
        # is number of bits changed in the hash
        # hash is 64 bits long
        # up to 5 hex digits can be different
        # 16 hex digits
        # 256b hash
        # 0xffff ffff ffff ffff ffff ffff ffff ffff
    if hash_orig - hash_input < HASH_DIFFERENCE:
        return imagenet_class_index[preds]
    else:
        return "IMAGE WAS TOO DIFFERENT"

# Function that takes care of the website's repeated image generation and edge conditions
@app.route('/', methods=['GET', 'POST'])
def index():

    response = None
    img = None
        # regen_image is a bool checking if session.get('img') is None
    regen_image = session.get('img') is None

    if session.get('level') is None:
        session['level'] = 0
        session['yolo'] = 0
        session.permanent = True
    
    if request.method == 'POST' and 'img' in session:
        file = request.files['file']
        img_bytes = file.read()
        
        image = bytes_to_image(img_bytes)
        (width, height) = image.size 
        depth = len(image.getbands())

        if width != 224 or height != 224 or depth != 3:
            response = f"Invalid image shape. Expecting 224 x 224 with 3 channels, got {width} x {height} with {depth} channels"
        else:   
            nonrobust = get_prediction(image_bytes=img_bytes, model = model_nonrobust, curr_image = session['img'])
            robust = get_prediction(image_bytes=img_bytes, model = model_robust, curr_image = session['img'])
            # robust model is the "ground truth", non-robust is the "bouncer"
            # cases:
                # bouncer does not want to let in horses, you want to let them in anyway
                # robust says horse, non-robust says horse: you have been detected
                # robust says not horse, non-robust says horse: you fail extra hard
                # robust says horse, non-robust says not horse: flag
                # robust says not horse, non-robust says not horse: they were let in but you didn't achieve the goal
            regen_image = True
            if robust != 'horse':
                response = "you snuck SOMETHING into the club but it wasn't a pwny (changed too much, ground truth thinks image is a: robust {}\tnonrobust {})".format(robust, nonrobust)
                session['yolo'] += 1
            elif robust == 'horse' and nonrobust != 'horse':
                session['level'] = session['level'] + 1
                session['yolo'] = 0
                response = "success! the bouncer thought your horse was a: {}".format(nonrobust)
                # response = "robust = {}, nonrobust = {}".format(robust, nonrobust)
            else: # robust == 'horse' and nonrobust == 'horse': 
                response = "bouncer saw through your disguise. bouncer: rules say \"NO HORSEPLAY\""
                session['yolo'] += 1
                # response += "\nrobust {}\tnonrobust {}".format(robust, nonrobust)
                # this is the most common fail condition
            if session['yolo'] > 3:
                session['yolo'] = 0
                session['level'] = 0
                response = "bouncer smacks you and you pass out, start over :)"

    if session['level'] >= MIN_LEVEL:
        response = FLAG
    elif response is None:
        response = "Hmm, alright, you've gotten %d horses into the club." % session['level']

    if regen_image or not MUST_REPEAT_CAPTCHA:
        img = gen_img()
        session['img'] = img
    else:
        img = session['img']

    return render_template('index.html', response = response, b64png = img)

@app.errorhandler(RuntimeError)
def error_handler(e):
    # TODO: How do you want to censor these?
    return render_template('error.html', error = str(e))

if __name__ == '__main__': # python app.py
    app.run(host='0.0.0.0')

# %%
! pip install imagehash

# %%
import io
import os
import random
import base64
import json
# from flask import Flask, jsonify, request, render_template, session
# from flask_kvsession import KVSessionExtension
import numpy as np

# from sqlalchemy import create_engine, MetaData
# from simplekv.db.sql import SQLAlchemyStore
from datetime import timedelta

# from werkzeug.utils import secure_filename
# from werkzeug.exceptions import HTTPException
from PIL import Image
import imagehash

from torchvision import models
import torchvision.transforms as transforms
import torchvision 
import torch.nn as nn
import torch

from torch.autograd import Variable

# %%
! mkdir ./models

# %%
imagenet_class_index = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

model_nonrobust = models.resnet18()
num_ftrs = model_nonrobust.fc.in_features
model_nonrobust.fc = nn.Linear(num_ftrs, len(imagenet_class_index))
model_nonrobust.load_state_dict(torch.load("./models/pwny_cifar_eps_0.pth", map_location = device))
model_ft = model_nonrobust.to(device)
model_nonrobust.eval()

# model_robust = models.resnet18()
# num_ftrs = model_robust.fc.in_features
# model_robust.fc = nn.Linear(num_ftrs, len(imagenet_class_index))
# model_robust.load_state_dict(torch.load("./models/pwny_cifar_eps_0.5.pth", map_location = device))
# model_ft = model_robust.to(device)
# model_robust.eval()

image_set = torchvision.datasets.CIFAR10(root='static/images', train=False, download=True)
# Out:
# Files already downloaded and verified

# %%
def gen_img():
    label = 0
    while label != 7:
        curr_image, label = image_set[random.randint(1, len(image_set))]

    resize_images = transforms.Compose([transforms.Resize(256),
                        transforms.CenterCrop(224)])
    curr_image = resize_images(curr_image)

    buffered = io.BytesIO()
    curr_image.save(buffered, format='png')
    return base64.b64encode(buffered.getvalue()).decode('utf-8')

# %%
def transform_image(image_bytes):
    my_transforms = transforms.Compose([
                        transforms.ToTensor(),
                        transforms.Normalize(
                            [0.485, 0.456, 0.406],
                            [0.229, 0.224, 0.225])])
    image = Image.open(io.BytesIO(image_bytes))
    return my_transforms(image).unsqueeze(0)

# %%
def tensor_to_image(tensor):
    tensor = tensor.detach().squeeze().numpy()
    tensor = tensor.transpose(1, 2, 0)
    tensor = (tensor * 255).astype(np.uint8)
    return Image.fromarray(tensor)

def image_to_tensor(img):
    tensor = np.array(img).astype(np.float32) / 255.0
    # HWC -> CHW
    tensor = tensor.transpose(2, 0, 1)
    tensor = tensor[None, :, :, :]  # add batch dimension
    return torch.tensor(tensor, requires_grad=True)

def bytes_to_image(img_data):
    import tempfile
    with tempfile.NamedTemporaryFile(suffix='.png') as tmp:
        tmp.write(img_data)
        tmp.flush()
        return Image.open(tmp.name)

def bytes_to_image(img_data):
    with tempfile.NamedTemporaryFile(suffix='.png') as tmp:
        tmp.write(img_data)
        tmp.flush()
        return Image.open(tmp.name)

# %%
def get_prediction(image_bytes, model, curr_image = None):
    inputs = transform_image(image_bytes=image_bytes)
    outputs = model(inputs)
    preds = torch.argmax(outputs, 1)
    original = Image.open(io.BytesIO(base64.b64decode(curr_image)))

    # "where the magic happens" - akshunna
    input_image = Image.open(io.BytesIO(image_bytes))
    hash_orig = imagehash.average_hash(original)
    hash_input = imagehash.average_hash(input_image)

        # currently HASH_DIFFERENCE is 5
        # is number of bits changed in the hash
        # hash is 64 bits long
        # up to 5 hex digits can be different
        # 16 hex digits
        # 256b hash
        # 0xffff ffff ffff ffff ffff ffff ffff ffff
    if hash_orig - hash_input < HASH_DIFFERENCE:
        return imagenet_class_index[preds]
    else:
        return "IMAGE WAS TOO DIFFERENT"

# %%
def solev_inshlh(lr):
    model_nonrobust = models.resnet18()
    num_ftrs = model_nonrobust.fc.in_features
    model_nonrobust.fc = nn.Linear(num_ftrs, len(imagenet_class_index))
    model_nonrobust.load_state_dict(torch.load("./models/pwny_cifar_eps_0.pth", map_location = device))
    model_ft = model_nonrobust.to(device)
    model_nonrobust.eval()

    img = Image.open("./test_images/index.png")
    img_tensor = image_to_tensor(img)
    Tensor = torch.cuda.FloatTensor
    img_tensor = Variable(Tensor(img_tensor.cuda()), requires_grad=True, )
    img_tensor.retain_grad = True
    lr = lr
    index = 7

    loss_fn = torch.nn.CrossEntropyLoss()
    j = 0
    while True:
        out = model_nonrobust(img_tensor.cuda())
        #print(out)
        #index = out.argmax().cpu().numpy()
        index = torch.argmax(out, dim=1)
        #print(index, out)
        # if index != 7:
        #     break

        target = torch.Tensor([4]).cuda()
        target = target.type(torch.long) 
        loss = loss_fn(out, target)
        loss.backward(retain_graph=True)

        img_tensor.data -= lr * img_tensor.grad.data

        # plt.imshow(img_tensor.detach().permute(0,2,3,1).squeeze(0))
        # plt.show()
        j += 1
        if j > 20:break

    img_back = tensor_to_image(img_tensor.cpu().detach())
    img_back.save("./res/1.png")

# %%
#!/usr/bin/python3

from PIL import Image
import requests
from base64 import b64decode as dec

url = "http://pwnies-please.chal.uiuc.tf/"
flag = False 

lr = 0.01

while not flag :
  sess = requests.session()
  lives = 0
  lr -= 0.0001
  print("-"*30, lr)
  for _ in range(54):
          resp = sess.get(url)
          img_data_bs64=resp.text.split("base64,")[1].split('"/>')[0]
          img_data=dec(img_data_bs64)
          with open("test_images/index.png","wb") as f:
              f.write(img_data)

          solev_inshlh(lr)

          files = {'file': open('res/1.png','rb')} #replace image.png with the modiffied image
          resp = sess.post(url,files=files)
          if 'uiuctf{' in resp.text:
              print(resp.text)
              flag = True
              break
          elif "success" in resp.text:
              print(f"{_} SUCESS")
          else:
              lives += 1
              print(f"{_} Fail , you have {4-lives} left")
              if lives > 3:
                  break
# Out:
# ------------------------------ 0.0099
# 0 SUCESS
# 1 SUCESS
# 2 Fail , you have 3 left
# 3 Fail , you have 2 left
# 4 Fail , you have 1 left
# 5 Fail , you have 0 left
# ------------------------------ 0.009800000000000001
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 SUCESS
# 3 SUCESS
# 4 Fail , you have 2 left
# 5 Fail , you have 1 left
# 6 Fail , you have 0 left
# ------------------------------ 0.009700000000000002
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ 0.009600000000000003
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 SUCESS
# 4 SUCESS
# 5 SUCESS
# 6 Fail , you have 1 left
# 7 Fail , you have 0 left
# ------------------------------ 0.009500000000000003
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 Fail , you have 2 left
# 3 SUCESS
# 4 SUCESS
# 5 SUCESS
# 6 Fail , you have 1 left
# 7 SUCESS
# 8 Fail , you have 0 left
# ------------------------------ 0.009400000000000004
# 0 SUCESS
# 1 SUCESS
# 2 SUCESS
# 3 SUCESS
# 4 SUCESS
# 5 SUCESS
# 6 SUCESS
# 7 Fail , you have 3 left
# 8 Fail , you have 2 left
# 9 SUCESS
# 10 Fail , you have 1 left
# 11 Fail , you have 0 left
# ------------------------------ 0.009300000000000004
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 SUCESS
# 4 SUCESS
# 5 SUCESS
# 6 Fail , you have 1 left
# 7 Fail , you have 0 left
# ------------------------------ 0.009200000000000005
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 SUCESS
# 4 Fail , you have 1 left
# 5 SUCESS
# 6 SUCESS
# 7 Fail , you have 0 left
# ------------------------------ 0.009100000000000006
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 SUCESS
# 3 SUCESS
# 4 Fail , you have 2 left
# 5 SUCESS
# 6 Fail , you have 1 left
# 7 SUCESS
# 8 SUCESS
# 9 SUCESS
# 10 Fail , you have 0 left
# ------------------------------ 0.009000000000000006
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 SUCESS
# 5 SUCESS
# 6 Fail , you have 0 left
# ------------------------------ 0.008900000000000007
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 SUCESS
# 4 Fail , you have 1 left
# 5 SUCESS
# 6 Fail , you have 0 left
# ------------------------------ 0.008800000000000007
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 SUCESS
# 3 SUCESS
# 4 Fail , you have 2 left
# 5 SUCESS
# 6 SUCESS
# 7 Fail , you have 1 left
# 8 Fail , you have 0 left
# ------------------------------ 0.008700000000000008
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 SUCESS
# 3 SUCESS
# 4 SUCESS
# 5 Fail , you have 1 left
# 6 Fail , you have 0 left
# ------------------------------ 0.008600000000000009
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 SUCESS
# 3 Fail , you have 2 left
# 4 Fail , you have 1 left
# 5 SUCESS
# 6 Fail , you have 0 left
# ------------------------------ 0.00850000000000001
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 SUCESS
# 3 Fail , you have 2 left
# 4 Fail , you have 1 left
# 5 Fail , you have 0 left
# ------------------------------ 0.00840000000000001
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ 0.00830000000000001
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 SUCESS
# 5 Fail , you have 0 left
# ------------------------------ 0.008200000000000011
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ 0.008100000000000012
# 0 SUCESS
# 1 SUCESS
# 2 Fail , you have 3 left
# 3 SUCESS
# 4 Fail , you have 2 left
# 5 Fail , you have 1 left
# 6 SUCESS
# 7 SUCESS
# 8 SUCESS
# 9 SUCESS
# 10 Fail , you have 0 left
# ------------------------------ 0.008000000000000012
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 SUCESS
# 3 SUCESS
# 4 SUCESS
# 5 Fail , you have 2 left
# 6 Fail , you have 1 left
# 7 SUCESS
# 8 SUCESS
# 9 Fail , you have 0 left
# ------------------------------ 0.007900000000000013
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 SUCESS
# 3 Fail , you have 2 left
# 4 SUCESS
# 5 Fail , you have 1 left
# 6 SUCESS
# 7 Fail , you have 0 left
# ------------------------------ 0.007800000000000013
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 SUCESS
# 5 SUCESS
# 6 SUCESS
# 7 SUCESS
# 8 SUCESS
# 9 Fail , you have 0 left
# ------------------------------ 0.007700000000000012
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ 0.007600000000000012
# 0 SUCESS
# 1 SUCESS
# 2 SUCESS
# 3 Fail , you have 3 left
# 4 Fail , you have 2 left
# 5 Fail , you have 1 left
# 6 Fail , you have 0 left
# ------------------------------ 0.007500000000000012
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 SUCESS
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ 0.007400000000000012
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 SUCESS
# 3 SUCESS
# 4 Fail , you have 2 left
# 5 SUCESS
# 6 Fail , you have 1 left
# 7 SUCESS
# 8 SUCESS
# 9 SUCESS
# 10 SUCESS
# 11 Fail , you have 0 left
# ------------------------------ 0.007300000000000011
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 SUCESS
# 3 SUCESS
# 4 SUCESS
# 5 SUCESS
# 6 SUCESS
# 7 Fail , you have 1 left
# 8
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 SUCESS
# 3 SUCESS
# 4 Fail , you have 2 left
# 5 SUCESS
# 6 Fail , you have 1 left
# 7 SUCESS
# 8 SUCESS
# 9 SUCESS
# 10 SUCESS
# 11 SUCESS
# 12 Fail , you have 0 left
# ------------------------------ -0.018099999999999943
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.018199999999999942
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.01829999999999994
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.01839999999999994
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 SUCESS
# 3 SUCESS
# 4 Fail , you have 2 left
# 5 Fail , you have 1 left
# 6 Fail , you have 0 left
# ------------------------------ -0.01849999999999994
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.01859999999999994
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 SUCESS
# 4 Fail , you have 1 left
# ...
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.043900000000000224
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.044000000000000226
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.04410000000000023
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04420000000000023
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.044300000000000235
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04440000000000024
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.04450000000000024
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 SUCESS
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.044600000000000244
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.044700000000000246
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04480000000000025
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04490000000000025
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.045000000000000255
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04510000000000026
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.04520000000000026
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.045300000000000264
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04540000000000027
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04550000000000027
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04560000000000027
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.045700000000000275
# 0 SUCESS
# 1 SUCESS
# 2 Fail , you have 3 left
# 3 Fail , you have 2 left
# 4 Fail , you have 1 left
# 5 SUCESS
# 6 Fail , you have 0 left
# ------------------------------ -0.04580000000000028
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04590000000000028
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.046000000000000284
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04610000000000029
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04620000000000029
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 SUCESS
# 3 Fail , you have 1 left
# 4 SUCESS
# 5 Fail , you have 0 left
# ------------------------------ -0.04630000000000029
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.046400000000000295
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.0465000000000003
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.0466000000000003
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.046700000000000304
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 SUCESS
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.04680000000000031
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04690000000000031
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.04700000000000031
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.047100000000000315
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04720000000000032
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04730000000000032
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 SUCESS
# 4 Fail , you have 0 left
# ------------------------------ -0.047400000000000324
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.04750000000000033
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04760000000000033
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04770000000000033
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 SUCESS
# 5 Fail , you have 0 left
# ------------------------------ -0.047800000000000335
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04790000000000034
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.04800000000000034
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.048100000000000344
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04820000000000035
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04830000000000035
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04840000000000035
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.048500000000000355
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 SUCESS
# 4 Fail , you have 0 left
# ------------------------------ -0.04860000000000036
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04870000000000036
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.048800000000000364
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04890000000000037
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04900000000000037
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04910000000000037
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.049200000000000375
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04930000000000038
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 SUCESS
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.04940000000000038
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.049500000000000384
# 0 SUCESS
# 1 SUCESS
# 2 Fail , you have 3 left
# 3 Fail , you have 2 left
# 4 Fail , you have 1 left
# 5 Fail , you have 0 left
# ------------------------------ -0.04960000000000039
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04970000000000039
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.04980000000000039
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 SUCESS
# 5 Fail , you have 0 left
# ------------------------------ -0.049900000000000395
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.0500000000000004
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.0501000000000004
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.050200000000000404
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05030000000000041
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05040000000000041
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05050000000000041
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.050600000000000415
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05070000000000042
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05080000000000042
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.050900000000000424
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05100000000000043
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.05110000000000043
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.05120000000000043
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 SUCESS
# 4 Fail , you have 0 left
# ------------------------------ -0.051300000000000436
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 Fail , you have 2 left
# 3 SUCESS
# 4 Fail , you have 1 left
# 5 Fail , you have 0 left
# ------------------------------ -0.05140000000000044
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05150000000000044
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.051600000000000444
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05170000000000045
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05180000000000045
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05190000000000045
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.052000000000000456
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05210000000000046
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.05220000000000046
# 0 SUCESS
# 1 Fail , you have 3 left
# 2 Fail , you have 2 left
# 3 SUCESS
# 4 Fail , you have 1 left
# 5 Fail , you have 0 left
# ------------------------------ -0.052300000000000464
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05240000000000047
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 SUCESS
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.05250000000000047
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05260000000000047
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.052700000000000476
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05280000000000048
# 0 Fail , you have 3 left
# 1 SUCESS
# 2 Fail , you have 2 left
# 3 Fail , you have 1 left
# 4 Fail , you have 0 left
# ------------------------------ -0.05290000000000048
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.053000000000000484
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05310000000000049
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05320000000000049
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05330000000000049
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.053400000000000496
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.0535000000000005
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.0536000000000005
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.053700000000000504
# 0 Fail , you have 3 left
# 1 Fail , you have 2 left
# 2 Fail , you have 1 left
# 3 Fail , you have 0 left
# ------------------------------ -0.05380000000000051
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-473-771706812fb1> in <module>()
#      17   for _ in range(54):
#      18           resp = sess.get(url)
# ---> 19           img_data_bs64=resp.text.split("base64,")[1].split('"/>')[0]
#      20           img_data=dec(img_data_bs64)
#      21           with open("test_images/index.png","wb") as f:
#
# IndexError: list index out of range

# %%
resp
# Out:
# <Response [500]>
