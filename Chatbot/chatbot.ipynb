# %%
import pandas as pd
import numpy as np
import torch 
import torch.nn as nn
import torch.nn.functional as F

import os

import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
def get_voc(df):
    english = " ".join(df["english"].tolist()).split(" ")
    eng_voc = list(dict.fromkeys(english))
    french  = " ".join(df["french"].tolist()).split(" ")
    fre_voc = list(dict.fromkeys(french))
    return {"eng_voc":eng_voc, "fre_voc":fre_voc}

# %%
MAX_LENGTH = 40

# %% [markdown]
# ## The encoder:

# %%
class Encoder_model(nn.Module):
    def __init__(self, input_size, hidden_size, vocabulary_size):
        super(Encoder_model, self).__init__()
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.embd = nn.Embedding(vocabulary_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        
    def forward(self, x, hidden):
        x = self.embd(torch.tensor(x).long())
        x, hidden = self.gru(x.view(1,1,-1), hidden)  
        x, hidden = self.gru(x.view(1,1,-1), hidden) 
        x, hidden = self.gru(x.view(1,1,-1), hidden) 
        x, hidden = self.gru(x.view(1,1,-1), hidden) 
            
        return x, hidden

    def inithidden(self):
        return torch.zeros(1,1,self.hidden_size).float().to(device=device)

# %% [markdown]
# ## The Decoder:

# %%
class Attention_decoder(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(Attention_decoder, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        #self.lstm = nn.LSTM(hidden_size, hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)
        
    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input)
        embedded = self.dropout(embedded)
        
        CONCAT = torch.cat((embedded, hidden[0,0]), 0)
        ATTN = self.attn(CONCAT)
       
        attn_weights = F.softmax(ATTN, dim=0)
       
        attn_applied = torch.bmm(attn_weights.view(1,1,MAX_LENGTH),
                                 encoder_outputs.view(1,MAX_LENGTH,-1))
        
        output = self.attn_combine(torch.cat((embedded, attn_applied[0,0]), 0))
        output = F.relu(output)
        
        output, hidden = self.gru(output.view(1,1,-1), hidden)
        output, hidden = self.gru(output.view(1,1,-1), hidden)
        output, hidden = self.gru(output.view(1,1,-1), hidden)
        output, hidden = self.gru(output.view(1,1,-1), hidden)
        
        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights
        
        
        return x, hidden

# %%
class data_loader():
    def __init__(self, dataset_path):

        
        df_ = pd.read_csv(dataset_path)
        df = pd.DataFrame()
        df["inputs"] = df_["inputs"]
        df["outputs"] = df_["outputs"]

        self.dataframe = df

        self.len = len(self.dataframe)
        
        
        
        vocab = []
        for line in df_["outputs"]:
            for word in line.split(" "):
                vocab.append(word)
        for line in df_["inputs"]:
            for word in line.split(" "):
                vocab.append(word)
        
        vocab = list(dict.fromkeys(vocab))
        vocab.sort()
        self.vocab = vocab
        self.len_vocab = len(self.vocab)
        
    def __len__(self):
        return self.len
    
    def __getitem__(self, idx):
        info = self.dataframe.iloc[idx]
        return {"input":info["inputs"], "output":info["outputs"]}
    
    def input2tensor(self, sentence):
        vocab = self.vocab
        
        idx_list = []
        words = sentence.strip().split(" ")

        for word in words:
            idx_list.append(vocab.index(word))
            
        return torch.tensor(data=idx_list).long()
    
    def get_random_indexes(self):
        L = list(range(0,self.len))
        random.shuffle(L)
        return L

# %% [markdown]
# ## The training yaaas:

# %%
def train(input, output, optim1, optim2, criterion):
    input = input.to(device=device)
    output = output.to(device=device)

    optim1.zero_grad()
    optim2.zero_grad()
    hidden = encoder.inithidden()
    loss = 0
    
    #The encoding phase
    encoder_outputs = torch.zeros(MAX_LENGTH, encoder.hidden_size).to(device=device)
    
    for i in range(len(input)):
        out , hidden = encoder(input[i], hidden)
        encoder_outputs[i] = out[0,0]
        
    luck = random.randint(0,1)

    if luck: #EASY TEACHER
        idx = output[0]    
        for i in range(len(output)-1):
            out, hidden, decoder_attention = decoder(idx, hidden, encoder_outputs)
            idx = torch.argmax(out)
            out = out.view(1,-1)
            y = output[i+1].view(1) 
            loss += criterion(out, y)
    else:    #ROUGH TEACHER
        for i in range(len(output)-1):
            out, hidden, decoder_attention = decoder(output[i], hidden, encoder_outputs)
            out = out.view(1,-1)
            y = output[i+1].view(1) 
            loss += criterion(out, y)

    
        
    loss.backward()
    optim1.step()
    optim2.step()
        
        
    return loss/len(output)

# %%
def evaluate(sentence): 
    vocab = sentences_dataset.vocab
    idxs = sentences_dataset.input2tensor(sentence).to(device=device)
    hidden = encoder.inithidden()
    encoder_outputs = torch.zeros(MAX_LENGTH, encoder.hidden_size).to(device=device)

    for i in range(len(idxs)):
        out, hidden = encoder(idxs[i], hidden)
        encoder_outputs[i] = out[0,0]

        
    idx = torch.tensor(13).long().to(device=device)
    for _ in range(10):
        out, hidden, __ = decoder(idx, hidden, encoder_outputs)
        idx = torch.argmax(out)
        if vocab[idx] == "<eos>":
            break
        print(vocab[idx], end=" ")
        
    print("")

# %%
sentences_dataset = data_loader(dataset_path="drive/My Drive/data/chatbot.csv")

# %%
len_vocab = sentences_dataset.len_vocab

encoder = Encoder_model(1, 256, len_vocab).to(device=device)
decoder = Attention_decoder( 256, len_vocab).to(device=device)


criterion   = nn.CrossEntropyLoss()
optim1      = torch.optim.Adam(encoder.parameters())
optim2      = torch.optim.Adam(decoder.parameters())

epochs      = 3
print_step  = 100
losses      = []

# %%
for epoch in range(1, epochs + 1):
    print("[EPOCH] Epoch number:", epoch)
    
    #get the list of indexes
    indexes = sentences_dataset.get_random_indexes()
    #loop over all indexes ( all sentences )
    for (i, idx) in enumerate(indexes):

        inp_out = sentences_dataset[idx]
        #get english and french sentences
        input  = inp_out["input"]
        output  = inp_out["output"]
        #print(input)
        #print(output)
        #creat arrays of tensors
        input = sentences_dataset.input2tensor(input)
        output = sentences_dataset.input2tensor(output)

        if len(input) <= MAX_LENGTH:
            loss = train(input, output, optim1, optim2, criterion)
            loss = loss.item()
            losses.append(loss)
            
            if i % 20 == 0:
                print("     [LOSS] Loss in step",i,"=", loss)
            if i % 100 == 0:
                evaluate("how are you doing")

            if i % 1000 == 0:
                torch.save(encoder.state_dict(), "drive/My Drive/data/chatbot_encoder")
                torch.save(decoder.state_dict(), "drive/My Drive/data/chatbot_decoder")
# Out:
# [EPOCH] Epoch number: 1
#      [LOSS] Loss in step 0 = 5.250875473022461
# I
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   # Remove the CWD from sys.path while we load stuff.
#      [LOSS] Loss in step 20 = 4.533743381500244
#      [LOSS] Loss in step 40 = 3.4902899265289307
#      [LOSS] Loss in step 60 = 4.215512752532959
#      [LOSS] Loss in step 80 = 5.537115573883057
#      [LOSS] Loss in step 100 = 5.7540411949157715
#
#      [LOSS] Loss in step 120 = 6.377120494842529
#      [LOSS] Loss in step 140 = 3.1568763256073
#      [LOSS] Loss in step 160 = 4.6624321937561035
#      [LOSS] Loss in step 180 = 4.99078893661499
#      [LOSS] Loss in step 200 = 5.610987186431885
# I can see the way
#      [LOSS] Loss in step 220 = 4.901833534240723
#      [LOSS] Loss in step 240 = 5.118227481842041
#      [LOSS] Loss in step 260 = 4.078178882598877
#      [LOSS] Loss in step 280 = 6.608697891235352
#      [LOSS] Loss in step 300 = 5.306408882141113
# I dont know
#      [LOSS] Loss in step 320 = 2.6803653240203857
#      [LOSS] Loss in step 340 = 6.167900085449219
#      [LOSS] Loss in step 360 = 1.9387190341949463
#      [LOSS] Loss in step 380 = 5.644211769104004
#      [LOSS] Loss in step 400 = 5.173585891723633
# the Devil
#      [LOSS] Loss in step 420 = 6.31422758102417
#      [LOSS] Loss in step 440 = 6.467284679412842
#      [LOSS] Loss in step 460 = 6.42863130569458
#      [LOSS] Loss in step 480 = 2.540994644165039
#      [LOSS] Loss in step 500 = 6.15275764465332
#
#      [LOSS] Loss in step 520 = 5.450028896331787
#      [LOSS] Loss in step 540 = 7.908224105834961
#      [LOSS] Loss in step 560 = 6.697126865386963
#      [LOSS] Loss in step 580 = 6.08720588684082
#      [LOSS] Loss in step 600 = 5.600602149963379
#
#      [LOSS] Loss in step 620 = 7.029270648956299
#      [LOSS] Loss in step 640 = 5.323985576629639
#      [LOSS] Loss in step 660 = 5.803005695343018
#      [LOSS] Loss in step 680 = 6.5901641845703125
#      [LOSS] Loss in step 700 = 4.633854866027832
#
#      [LOSS] Loss in step 720 = 6.852272033691406
#      [LOSS] Loss in step 740 = 3.6847212314605713
#      [LOSS] Loss in step 760 = 4.0117387771606445
#      [LOSS] Loss in step 780 = 5.213299751281738
#      [LOSS] Loss in step 800 = 6.458561897277832
# I dont know
#      [LOSS] Loss in step 820 = 5.446076393127441
#      [LOSS] Loss in step 840 = 5.114878177642822
#      [LOSS] Loss in step 860 = 7.855396270751953
#      [LOSS] Loss in step 880 = 3.6597249507904053
#      [LOSS] Loss in step 900 = 9.456727981567383
#
#      [LOSS] Loss in step 920 = 4.426346302032471
#      [LOSS] Loss in step 940 = 6.26073694229126
#      [LOSS] Loss in step 960 = 6.2963056564331055
#      [LOSS] Loss in step 980 = 8.338156700134277
#      [LOSS] Loss in step 1000 = 3.2131314277648926
#
#      [LOSS] Loss in step 1020 = 6.101757526397705
#      [LOSS] Loss in step 1040 = 3.4818170070648193
#      [LOSS] Loss in step 1060 = 7.055692672729492
#      [LOSS] Loss in step 1080 = 9.649843215942383
#      [LOSS] Loss in step 1100 = 8.273122787475586
#
#      [LOSS] Loss in step 1120 = 9.083293914794922
#      [LOSS] Loss in step 1140 = 7.2328972816467285
#      [LOSS] Loss in step 1160 = 7.299830913543701
#      [LOSS] Loss in step 1180 = 5.682652950286865
#      [LOSS] Loss in step 1200 = 5.654797554016113
#
#      [LOSS] Loss in step 1220 = 8.019766807556152
#      [LOSS] Loss in step 1240 = 1.8148622512817383
#      [LOSS] Loss in step 1260 = 6.954925537109375
#      [LOSS] Loss in step 1280 = 2.5523409843444824
#      [LOSS] Loss in step 1300 = 5.461474895477295
#
#      [LOSS] Loss in step 1320 = 6.246635437011719
#      [LOSS] Loss in step 1340 = 5.876226902008057
#      [LOSS] Loss in step 1360 = 4.616561412811279
#      [LOSS] Loss in step 1380 = 8.73247241973877
#      [LOSS] Loss in step 1400 = 7.244554042816162
# I dont know
#      [LOSS] Loss in step 1420 = 5.330666542053223
#      [LOSS] Loss in step 1440 = 7.373257637023926
#      [LOSS] Loss in step 1460 = 4.47671365737915
#      [LOSS] Loss in step 1480 = 9.09128189086914
#      [LOSS] Loss in step 1500 = 6.287125587463379
# I dont know you
#      [LOSS] Loss in step 1520 = 6.0098772048950195
#      [LOSS] Loss in step 1540 = 7.688754081726074
#      [LOSS] Loss in step 1560 = 6.510608196258545
#      [LOSS] Loss in step 1580 = 10.369104385375977
#      [LOSS] Loss in step 1600 = 3.8571105003356934
# I
#      [LOSS] Loss in step 1620 = 5.301746368408203
#      [LOSS] Loss in step 1640 = 8.941400527954102
#      [LOSS] Loss in step 1660 = 2.8896396160125732
#      [LOSS] Loss in step 1680 = 4.307448387145996
#      [LOSS] Loss in step 1700 = 7.4862589836120605
# I dont know
#      [LOSS] Loss in step 1720 = 8.00446605682373
#      [LOSS] Loss in step 1740 = 4.391132831573486
#      [LOSS] Loss in step 1760 = 6.483174800872803
#      [LOSS] Loss in step 1780 = 4.166465759277344
#      [LOSS] Loss in step 1800 = 5.075710296630859
# I
#      [LOSS] Loss in step 1820 = 6.1349263191223145
#      [LOSS] Loss in step 1840 = 7.659393310546875
#      [LOSS] Loss in step 1860 = 6.296395301818848
#      [LOSS] Loss in step 1880 = 4.845002174377441
#      [LOSS] Loss in step 1900 = 6.387350082397461
# I
#      [LOSS] Loss in step 1920 = 3.6233441829681396
#      [LOSS] Loss in step 1940 = 7.268981456756592
#      [LOSS] Loss in step 1960 = 6.436132907867432
#      [LOSS] Loss in step 1980 = 4.7315521240234375
#      [LOSS] Loss in step 2000 = 7.052143096923828
# I you
#      [LOSS] Loss in step 2020 = 4.1505255699157715
#      [LOSS] Loss in step 2040 = 2.434556484222412
#      [LOSS] Loss in step 2060 = 5.194352626800537
#      [LOSS] Loss in step 2080 = 5.252996921539307
#      [LOSS] Loss in step 2100 = 3.9715054035186768
# I dont you
#      [LOSS] Loss in step 2120 = 6.929154396057129
#      [LOSS] Loss in step 2140 = 7.545315742492676
#      [LOSS] Loss in step 2160 = 4.431847095489502
#      [LOSS] Loss in step 2180 = 6.153676986694336
#      [LOSS] Loss in step 2200 = 3.1299493312835693
#
#      [LOSS] Loss in step 2220 = 6.867158889770508
#      [LOSS] Loss in step 2240 = 7.290094375610352
#      [LOSS] Loss in step 2260 = 7.056214332580566
#      [LOSS] Loss in step 2280 = 3.1499853134155273
#      [LOSS] Loss in step 2300 = 5.436141014099121
# I dont
#      [LOSS] Loss in step 2320 = 9.777040481567383
#      [LOSS] Loss in step 2340 = 5.022303581237793
#      [LOSS] Loss in step 2360 = 8.333306312561035
#      [LOSS] Loss in step 2380 = 5.766637802124023
#      [LOSS] Loss in step 2400 = 4.40650749206543
# I dont know
#      [LOSS] Loss in step 2420 = 6.307849884033203
#      [LOSS] Loss in step 2440 = 7.355066299438477
#      [LOSS] Loss in step 2460 = 6.165626525878906
#      [LOSS] Loss in step 2480 = 5.892669200897217
#      [LOSS] Loss in step 2500 = 3.6975631713867188
#
#      [LOSS] Loss in step 2520 = 5.653537273406982
#      [LOSS] Loss in step 2540 = 4.518060684204102
#      [LOSS] Loss in step 2560 = 7.362768650054932
#      [LOSS] Loss in step 2580 = 4.71198844909668
#      [LOSS] Loss in step 2600 = 3.157626152038574
# I
#      [LOSS] Loss in step 2620 = 6.099782943725586
#      [LOSS] Loss in step 2640 = 6.014839172363281
#      [LOSS] Loss in step 2660 = 5.502945423126221
#      [LOSS] Loss in step 2680 = 5.2215423583984375
#      [LOSS] Loss in step 2700 = 5.007047176361084
#
#      [LOSS] Loss in step 2720 = 6.209527492523193
#      [LOSS] Loss in step 2740 = 4.9330291748046875
#      [LOSS] Loss in step 2760 = 3.7231802940368652
#      [LOSS] Loss in step 2780 = 5.226571559906006
#      [LOSS] Loss in step 2800 = 5.95702600479126
# I know you know you know you know you know
#      [LOSS] Loss in step 2820 = 3.672557830810547
#      [LOSS] Loss in step 2840 = 6.869326591491699
#      [LOSS] Loss in step 2860 = 6.748631954193115
#      [LOSS] Loss in step 2880 = 5.957498073577881
#      [LOSS] Loss in step 2900 = 6.080114841461182
#
#      [LOSS] Loss in step 2920 = 4.937608242034912
#      [LOSS] Loss in step 2940 = 6.131642818450928
#      [LOSS] Loss in step 2960 = 8.369338035583496
#      [LOSS] Loss in step 2980 = 6.656001567840576
#      [LOSS] Loss in step 3000 = 6.798752784729004
#
#      [LOSS] Loss in step 3020 = 5.7095208168029785
#      [LOSS] Loss in step 3040 = 4.817794322967529
#      [LOSS] Loss in step 3060 = 6.5909905433654785
#      [LOSS] Loss in step 3080 = 5.58992862701416
#      [LOSS] Loss in step 3100 = 5.851655960083008
#
#      [LOSS] Loss in step 3120 = 1.8581937551498413
#      [LOSS] Loss in step 3140 = 6.316695690155029
#      [LOSS] Loss in step 3160 = 4.561467170715332
#      [LOSS] Loss in step 3180 = 3.4383082389831543
#      [LOSS] Loss in step 3200 = 6.570366859436035
#
#      [LOSS] Loss in step 3220 = 4.893664836883545
#      [LOSS] Loss in step 3240 = 6.56644344329834
#      [LOSS] Loss in step 3260 = 5.3723578453063965
#      [LOSS] Loss in step 3280 = 5.64035177230835
#      [LOSS] Loss in step 3300 = 7.278353214263916
#
#      [LOSS] Loss in step 3320 = 3.462615966796875
#      [LOSS] Loss in step 3340 = 3.899616003036499
#      [LOSS] Loss in step 3360 = 5.551373481750488
#      [LOSS] Loss in step 3380 = 5.343517780303955
#      [LOSS] Loss in step 3400 = 4.2623610496521
#
#      [LOSS] Loss in step 3420 = 3.8630027770996094
#      [LOSS] Loss in step 3440 = 5.066464424133301
#      [LOSS] Loss in step 3460 = 7.303907871246338
#      [LOSS] Loss in step 3480 = 3.8663790225982666
#      [LOSS] Loss in step 3500 = 4.669792175292969
#
#      [LOSS] Loss in step 3520 = 3.5528454780578613
#      [LOSS] Loss in step 3540 = 3.9912688732147217
#      [LOSS] Loss in step 3560 = 2.999257802963257
#      [LOSS] Loss in step 3580 = 7.076544284820557
#      [LOSS] Loss in step 3600 = 4.87251615524292
# the way
#      [LOSS] Loss in step 3620 = 4.106125831604004
#      [LOSS] Loss in step 3640 = 3.6604278087615967
#      [LOSS] Loss in step 3660 = 6.7918171882629395
#      [LOSS] Loss in step 3680 = 8.972724914550781
#      [LOSS] Loss in step 3700 = 7.360809326171875
#
#      [LOSS] Loss in step 3720 = 3.967705488204956
#      [LOSS] Loss in step 3740 = 6.133577346801758
#      [LOSS] Loss in step 3760 = 5.819798469543457
#      [LOSS] Loss in step 3780 = 2.5551910400390625
#      [LOSS] Loss in step 3800 = 5.809756755828857
# the way
#      [LOSS] Loss in step 3820 = 3.705566883087158
#      [LOSS] Loss in step 3840 = 4.912928104400635
#      [LOSS] Loss in step 3860 = 3.5886826515197754
#      [LOSS] Loss in step 3880 = 7.412581443786621
#      [LOSS] Loss in step 3900 = 3.6384119987487793
# the way
#      [LOSS] Loss in step 3920 = 7.164483070373535
#      [LOSS] Loss in step 3940 = 6.640562534332275
#      [LOSS] Loss in step 3960 = 8.49814224243164
#      [LOSS] Loss in step 3980 = 7.8304924964904785
#      [LOSS] Loss in step 4000 = 7.185964584350586
# the way
#      [LOSS] Loss in step 4020 = 4.515695095062256
#      [LOSS] Loss in step 4040 = 6.384332656860352
#      [LOSS] Loss in step 4060 = 3.1563806533813477
#      [LOSS] Loss in step 4080 = 4.445282936096191
#      [LOSS] Loss in step 4100 = 4.772515773773193
#
#      [LOSS] Loss in step 4120 = 5.24740743637085
#      [LOSS] Loss in step 4140 = 6.908336639404297
#      [LOSS] Loss in step 4160 = 4.14985990524292
#      [LOSS] Loss in step 4180 = 4.763813495635986
#      [LOSS] Loss in step 4200 = 4.587686538696289
#
#      [LOSS] Loss in step 4220 = 8.358890533447266
#      [LOSS] Loss in step 4240 = 5.432559013366699
#      [LOSS] Loss in step 4260 = 7.623076915740967
#      [LOSS] Loss in step 4280 = 5.028976917266846
#      [LOSS] Loss in step 4300 = 5.825754642486572
# the way
#      [LOSS] Loss in step 4320 = 7.0439558029174805
#      [LOSS] Loss in step 4340 = 5.998197555541992
#      [LOSS] Loss in step 4360 = 3.0705504417419434
#      [LOSS] Loss in step 4380 = 6.157253742218018
#      [LOSS] Loss in step 4400 = 4.180370330810547
#
#      [LOSS] Loss in step 4420 = 5.9829325675964355
#      [LOSS] Loss in step 4440 = 5.632646083831787
#      [LOSS] Loss in step 4460 = 5.452011585235596
#      [LOSS] Loss in step 4480 = 5.329396724700928
#      [LOSS] Loss in step 4500 = 4.056026458740234
# a
#      [LOSS] Loss in step 4520 = 4.844028472900391
#      [LOSS] Loss in step 4540 = 4.322142601013184
#      [LOSS] Loss in step 4560 = 4.2188544273376465
#      [LOSS] Loss in step 4580 = 6.580207347869873
#      [LOSS] Loss in step 4600 = 3.5488264560699463
#
#      [LOSS] Loss in step 4620 = 4.087862491607666
#      [LOSS] Loss in step 4640 = 5.625527381896973
#      [LOSS] Loss in step 4660 = 4.764072895050049
#      [LOSS] Loss in step 4680 = 4.391145706176758
#      [LOSS] Loss in step 4700 = 6.677680492401123
#
#      [LOSS] Loss in step 4720 = 4.724968910217285
#      [LOSS] Loss in step 4740 = 4.833719730377197
#      [LOSS] Loss in step 4760 = 6.171856880187988
#      [LOSS] Loss in step 4780 = 6.551766395568848
#      [LOSS] Loss in step 4800 = 5.6168293952941895
# I
#      [LOSS] Loss in step 4820 = 8.132644653320312
#      [LOSS] Loss in step 4840 = 7.43565034866333
#      [LOSS] Loss in step 4860 = 6.717009544372559
#      [LOSS] Loss in step 4880 = 5.067284107208252
#      [LOSS] Loss in step 4900 = 6.464700222015381
# I I
#      [LOSS] Loss in step 4920 = 7.289123058319092
#      [LOSS] Loss in step 4940 = 7.544314861297607
#      [LOSS] Loss in step 4960 = 4.412525653839111
#      [LOSS] Loss in step 4980 = 5.53673791885376
#      [LOSS] Loss in step 5000 = 4.830585479736328
#
#      [LOSS] Loss in step 5020 = 2.9125640392303467
#      [LOSS] Loss in step 5040 = 5.804901123046875
#      [LOSS] Loss in step 5060 = 2.3332905769348145
#      [LOSS] Loss in step 5080 = 6.165775775909424
#      [LOSS] Loss in step 5100 = 6.989887714385986
#
#      [LOSS] Loss in step 5120 = 4.903478622436523
#      [LOSS] Loss in step 5140 = 6.800461769104004
#      [LOSS] Loss in step 5160 = 5.610536098480225
#      [LOSS] Loss in step 5180 = 4.107821464538574
#      [LOSS] Loss in step 5200 = 6.2861647605896
# I
#      [LOSS] Loss in step 5220 = 4.579486846923828
#      [LOSS] Loss in step 5240 = 6.390402793884277
#      [LOSS] Loss in step 5260 = 5.486130237579346
#      [LOSS] Loss in step 5280 = 5.398676872253418
#      [LOSS] Loss in step 5300 = 5.471542835235596
# You dont
#      [LOSS] Loss in step 5320 = 3.2355926036834717
#      [LOSS] Loss in step 5340 = 7.553605079650879
#      [LOSS] Loss in step 5360 = 3.0082850456237793
#      [LOSS] Loss in step 5380 = 5.446048736572266
#      [LOSS] Loss in step 5400 = 4.658713340759277
# You
#      [LOSS] Loss in step 5420 = 6.126550674438477
#      [LOSS] Loss in step 5440 = 5.4663405418396
#      [LOSS] Loss in step 5460 = 4.567642688751221
#      [LOSS] Loss in step 5480 = 5.934604167938232
#      [LOSS] Loss in step 5500 = 6.503024101257324
# I I
#      [LOSS] Loss in step 5520 = 5.934908390045166
#      [LOSS] Loss in step 5540 = 5.571146488189697
#      [LOSS] Loss in step 5560 = 3.6535580158233643
#      [LOSS] Loss in step 5580 = 6.10187292098999
#      [LOSS] Loss in step 5600 = 3.875119209289551
#
#      [LOSS] Loss in step 5620 = 7.555673599243164
#      [LOSS] Loss in step 5640 = 5.6234331130981445
#      [LOSS] Loss in step 5660 = 5.555412769317627
#      [LOSS] Loss in step 5680 = 6.9146881103515625
#      [LOSS] Loss in step 5700 = 6.067296504974365
# I dont know you
#      [LOSS] Loss in step 5720 = 4.9033026695251465
#      [LOSS] Loss in step 5740 = 6.648106098175049
#      [LOSS] Loss in step 5760 = 3.4962711334228516
#      [LOSS] Loss in step 5780 = 6.761955261230469
#      [LOSS] Loss in step 5800 = 4.8801751136779785
# I
#      [LOSS] Loss in step 5820 = 6.788497447967529
#      [LOSS] Loss in step 5840 = 6.075904369354248
#      [LOSS] Loss in step 5860 = 7.882568359375
#      [LOSS] Loss in step 5880 = 8.562312126159668
#      [LOSS] Loss in step 5900 = 8.512028694152832
#
#      [LOSS] Loss in step 5920 = 5.548950672149658
#      [LOSS] Loss in step 5940 = 6.308751583099365
#      [LOSS] Loss in step 5960 = 6.391200542449951
#      [LOSS] Loss in step 5980 = 5.85246467590332
#      [LOSS] Loss in step 6000 = 5.6258063316345215
# I
#      [LOSS] Loss in step 6020 = 5.11586332321167
#      [LOSS] Loss in step 6040 = 5.8595967292785645
#      [LOSS] Loss in step 6060 = 2.0929360389709473
#      [LOSS] Loss in step 6080 = 5.091761112213135
#      [LOSS] Loss in step 6100 = 5.648428440093994
# I
#      [LOSS] Loss in step 6120 = 6.107864856719971
#      [LOSS] Loss in step 6140 = 5.305184841156006
#      [LOSS] Loss in step 6160 = 4.59014892578125
#      [LOSS] Loss in step 6180 = 6.426939487457275
#      [LOSS] Loss in step 6200 = 4.463925838470459
# I dont know you
#      [LOSS] Loss in step 6220 = 4.017431735992432
#      [LOSS] Loss in step 6240 = 7.079783916473389
#      [LOSS] Loss in step 6260 = 5.1021246910095215
#      [LOSS] Loss in step 6280 = 2.7895352840423584
#      [LOSS] Loss in step 6300 = 3.9627177715301514
# I you
#      [LOSS] Loss in step 6320 = 5.660106182098389
#      [LOSS] Loss in step 6340 = 6.525783538818359
#      [LOSS] Loss in step 6360 = 5.556652069091797
#      [LOSS] Loss in step 6380 = 3.443838357925415
#      [LOSS] Loss in step 6400 = 6.037764072418213
# I you
#      [LOSS] Loss in step 6420 = 2.819253444671631
#      [LOSS] Loss in step 6440 = 6.336641788482666
#      [LOSS] Loss in step 6460 = 6.649845123291016
#      [LOSS] Loss in step 6480 = 5.853819847106934
#      [LOSS] Loss in step 6500 = 7.106105804443359
# You dont
#      [LOSS] Loss in step 6520 = 3.6514790058135986
#      [LOSS] Loss in step 6540 = 4.887104034423828
#      [LOSS] Loss in step 6560 = 6.183684349060059
#      [LOSS] Loss in step 6580 = 4.561388969421387
#      [LOSS] Loss in step 6600 = 3.330432415008545
# I
#      [LOSS] Loss in step 6620 = 5.582376480102539
#      [LOSS] Loss in step 6640 = 4.511483192443848
#      [LOSS] Loss in step 6660 = 2.638777732849121
#      [LOSS] Loss in step 6680 = 4.966013431549072
#      [LOSS] Loss in step 6700 = 7.307032108306885
# I you
#      [LOSS] Loss in step 6720 = 5.310525417327881
#      [LOSS] Loss in step 6740 = 3.747537136077881
#      [LOSS] Loss in step 6760 = 7.103888511657715
#      [LOSS] Loss in step 6780 = 1.833315372467041
#      [LOSS] Loss in step 6800 = 5.368094444274902
# I dont
#      [LOSS] Loss in step 6820 = 6.224160194396973
#      [LOSS] Loss in step 6840 = 5.521860122680664
#      [LOSS] Loss in step 6860 = 6.638556480407715
#      [LOSS] Loss in step 6880 = 5.162490367889404
#      [LOSS] Loss in step 6900 = 3.576936721801758
# You dont
#      [LOSS] Loss in step 6920 = 7.240542888641357
#      [LOSS] Loss in step 6940 = 5.262902736663818
#      [LOSS] Loss in step 6960 = 6.199999809265137
#      [LOSS] Loss in step 6980 = 3.010944128036499
#      [LOSS] Loss in step 7000 = 2.5069737434387207
# I
#      [LOSS] Loss in step 7020 = 5.898319721221924
#      [LOSS] Loss in step 7040 = 5.754128932952881
#      [LOSS] Loss in step 7060 = 4.69828987121582
#      [LOSS] Loss in step 7080 = 5.049465656280518
#      [LOSS] Loss in step 7100 = 2.750153064727783
# You know you
#      [LOSS] Loss in step 7120 = 5.992629051208496
#      [LOSS] Loss in step 7140 = 2.9254722595214844
#      [LOSS] Loss in step 7160 = 9.018698692321777
#      [LOSS] Loss in step 7180 = 5.298558712005615
#      [LOSS] Loss in step 7200 = 3.919257402420044
# I you
#      [LOSS] Loss in step 7220 = 8.576904296875
#      [LOSS] Loss in step 7240 = 6.11890172958374
#      [LOSS] Loss in step 7260 = 6.078495025634766
#      [LOSS] Loss in step 7280 = 3.398491621017456
#      [LOSS] Loss in step 7300 = 2.0073306560516357
# I dont
#      [LOSS] Loss in step 7320 = 4.002641677856445
#      [LOSS] Loss in step 7340 = 4.829373359680176
#      [LOSS] Loss in step 7360 = 4.727053165435791
#      [LOSS] Loss in step 7380 = 7.105874061584473
#      [LOSS] Loss in step 7400 = 5.323266506195068
# No
#      [LOSS] Loss in step 7420 = 6.1425323486328125
#      [LOSS] Loss in step 7440 = 5.461203575134277
#      [LOSS] Loss in step 7460 = 5.449089050292969
#      [LOSS] Loss in step 7480 = 4.180688381195068
#      [LOSS] Loss in step 7500 = 3.4025723934173584
# I
#      [LOSS] Loss in step 7520 = 4.582380294799805
#      [LOSS] Loss in step 7540 = 2.2098608016967773
#      [LOSS] Loss in step 7560 = 5.60898494720459
#      [LOSS] Loss in step 7580 = 5.8501434326171875
#      [LOSS] Loss in step 7600 = 6.418701171875
# I
#      [LOSS] Loss in step 7620 = 4.298285484313965
#      [LOSS] Loss in step 7640 = 6.153341293334961
#      [LOSS] Loss in step 7660 = 5.432328701019287
#      [LOSS] Loss in step 7680 = 4.586378574371338
#      [LOSS] Loss in step 7700 = 9.491994857788086
# I
#      [LOSS] Loss in step 7720 = 3.827382802963257
#      [LOSS] Loss in step 7740 = 7.253490924835205
#      [LOSS] Loss in step 7760 = 6.118644714355469
#      [LOSS] Loss in step 7780 = 3.6843173503875732
#      [LOSS] Loss in step 7800 = 5.258022785186768
# I dont
#      [LOSS] Loss in step 7820 = 2.6239733695983887
#      [LOSS] Loss in step 7840 = 4.304024696350098
#      [LOSS] Loss in step 7860 = 5.767416000366211
#      [LOSS] Loss in step 7880 = 4.255528450012207
#      [LOSS] Loss in step 7900 = 6.030917167663574
# I dont
#      [LOSS] Loss in step 7920 = 5.153113842010498
#      [LOSS] Loss in step 7940 = 3.5372707843780518
#      [LOSS] Loss in step 7960 = 5.439004898071289
#      [LOSS] Loss in step 7980 = 6.803764820098877
#      [LOSS] Loss in step 8000 = 4.794871807098389
# I
#      [LOSS] Loss in step 8020 = 3.5401155948638916
#      [LOSS] Loss in step 8040 = 7.386003017425537
#      [LOSS] Loss in step 8060 = 6.364716053009033
#      [LOSS] Loss in step 8080 = 4.545414447784424
#      [LOSS] Loss in step 8100 = 6.4397664070129395
# I dont you
#      [LOSS] Loss in step 8120 = 2.992928981781006
#      [LOSS] Loss in step 8140 = 6.3452348709106445
#      [LOSS] Loss in step 8160 = 6.226350784301758
#      [LOSS] Loss in step 8180 = 5.29125452041626
#      [LOSS] Loss in step 8200 = 2.9509263038635254
# You
#      [LOSS] Loss in step 8220 = 5.052628040313721
#      [LOSS] Loss in step 8240 = 2.2397477626800537
#      [LOSS] Loss in step 8260 = 7.641353130340576
#      [LOSS] Loss in step 8280 = 7.674273490905762
#      [LOSS] Loss in step 8300 = 1.848479986190796
# I
#      [LOSS] Loss in step 8320 = 5.515164375305176
#      [LOSS] Loss in step 8340 = 5.565288543701172
#      [LOSS] Loss in step 8360 = 4.817581653594971
#      [LOSS] Loss in step 8380 = 3.4452900886535645
#      [LOSS] Loss in step 8400 = 4.146520614624023
# I to know that
#      [LOSS] Loss in step 8420 = 3.20294451713562
#      [LOSS] Loss in step 8440 = 2.817183017730713
#      [LOSS] Loss in step 8460 = 8.653654098510742
#      [LOSS] Loss in step 8480 = 2.0054924488067627
#      [LOSS] Loss in step 8500 = 3.6452369689941406
# I dont
#      [LOSS] Loss in step 8520 = 4.202556610107422
#      [LOSS] Loss in step 8540 = 5.980082035064697
#      [LOSS] Loss in step 8560 = 5.133983612060547
#      [LOSS] Loss in step 8580 = 5.02463436126709
#      [LOSS] Loss in step 8600 = 5.882348537445068
# No
#      [LOSS] Loss in step 8620 = 5.543959617614746
#      [LOSS] Loss in step 8640 = 5.398338794708252
#      [LOSS] Loss in step 8660 = 6.288181781768799
#      [LOSS] Loss in step 8680 = 6.82340145111084
#      [LOSS] Loss in step 8700 = 5.483084201812744
#
#      [LOSS] Loss in step 8720 = 5.107404708862305
#      [LOSS] Loss in step 8740 = 5.3766069412231445
#      [LOSS] Loss in step 8760 = 5.15703010559082
#      [LOSS] Loss in step 8780 = 5.5319695472717285
#      [LOSS] Loss in step 8800 = 4.600924491882324
#
#      [LOSS] Loss in step 8820 = 6.379260540008545
#      [LOSS] Loss in step 8840 = 6.436945915222168
#      [LOSS] Loss in step 8860 = 6.7420454025268555
#      [LOSS] Loss in step 8880 = 5.093823432922363
#      [LOSS] Loss in step 8900 = 2.6789984703063965
#
#      [LOSS] Loss in step 8920 = 6.000189781188965
#      [LOSS] Loss in step 8940 = 4.101493835449219
#      [LOSS] Loss in step 8960 = 5.000085353851318
#      [LOSS] Loss in step 8980 = 6.269150733947754
#      [LOSS] Loss in step 9000 = 6.050401210784912
#
#      [LOSS] Loss in step 9020 = 3.8539750576019287
#      [LOSS] Loss in step 9040 = 4.140096187591553
#      [LOSS] Loss in step 9060 = 7.025147438049316
#      [LOSS] Loss in step 9080 = 6.022414207458496
#      [LOSS] Loss in step 9100 = 5.289890289306641
# You dont
#      [LOSS] Loss in step 9120 = 6.995156764984131
#      [LOSS] Loss in step 9140 = 6.96852970123291
#      [LOSS] Loss in step 9160 = 5.5133256912231445
#      [LOSS] Loss in step 9180 = 3.5255520343780518
#      [LOSS] Loss in step 9200 = 4.082306861877441
# I
#      [LOSS] Loss in step 9220 = 6.095954895019531
#      [LOSS] Loss in step 9240 = 6.285460948944092
#      [LOSS] Loss in step 9260 = 7.442677974700928
#      [LOSS] Loss in step 9280 = 6.550848007202148
#      [LOSS] Loss in step 9300 = 7.288060665130615
#
#      [LOSS] Loss in step 9320 = 3.5409750938415527
#      [LOSS] Loss in step 9340 = 3.7163665294647217
#      [LOSS] Loss in step 9360 = 7.393411159515381
#      [LOSS] Loss in step 9380 = 6.0861334800720215
#      [LOSS] Loss in step 9400 = 7.3639068603515625
# No
#      [LOSS] Loss in step 9420 = 3.97072172164917
#      [LOSS] Loss in step 9440 = 6.4434494972229
#      [LOSS] Loss in step 9460 = 3.566547393798828
#      [LOSS] Loss in step 9480 = 6.259670257568359
#      [LOSS] Loss in step 9500 = 4.7820258140563965
# I
#      [LOSS] Loss in step 9520 = 3.63785982131958
#      [LOSS] Loss in step 9540 = 4.76587438583374
#      [LOSS] Loss in step 9560 = 6.158184051513672
#      [LOSS] Loss in step 9580 = 5.861745357513428
#      [LOSS] Loss in step 9600 = 2.4785022735595703
# I dont
#      [LOSS] Loss in step 9620 = 5.4566802978515625
#      [LOSS] Loss in step 9640 = 2.904970407485962
#      [LOSS] Loss in step 9660 = 3.742655038833618
#      [LOSS] Loss in step 9680 = 5.379103660583496
#      [LOSS] Loss in step 9700 = 5.442676067352295
# I dont
#      [LOSS] Loss in step 9720 = 6.78067684173584
#      [LOSS] Loss in step 9740 = 6.326900005340576
#      [LOSS] Loss in step 9760 = 5.902581214904785
#      [LOSS] Loss in step 9780 = 2.304891586303711
#      [LOSS] Loss in step 9800 = 4.918315887451172
# I
#      [LOSS] Loss in step 9820 = 4.918853759765625
#      [LOSS] Loss in step 9840 = 3.3546645641326904
#      [LOSS] Loss in step 9860 = 7.914303302764893
#      [LOSS] Loss in step 9880 = 8.506728172302246
#      [LOSS] Loss in step 9900 = 5.294858455657959
# I dont
#      [LOSS] Loss in step 9920 = 5.248518943786621
#      [LOSS] Loss in step 9940 = 3.9666526317596436
#      [LOSS] Loss in step 9960 = 4.5815839767456055
#      [LOSS] Loss in step 9980 = 6.13289737701416
#      [LOSS] Loss in step 10000 = 1.825061321258545
# I
#      [LOSS] Loss in step 10020 = 3.634341239929199
#      [LOSS] Loss in step 10040 = 6.631368637084961
#      [LOSS] Loss in step 10060 = 6.863128185272217
#      [LOSS] Loss in step 10080 = 6.4070353507995605
#      [LOSS] Loss in step 10100 = 4.339096546173096
# I
#      [LOSS] Loss in step 10120 = 5.114487648010254
#      [LOSS] Loss in step 10140 = 5.901776313781738
#      [LOSS] Loss in step 10160 = 3.8633604049682617
#      [LOSS] Loss in step 10180 = 3.433932304382324
#      [LOSS] Loss in step 10200 = 3.18497896194458
# I I dont
#      [LOSS] Loss in step 10220 = 4.798741340637207
#      [LOSS] Loss in step 10240 = 2.3216805458068848
#      [LOSS] Loss in step 10260 = 4.963215351104736
#      [LOSS] Loss in step 10280 = 6.077155113220215
#      [LOSS] Loss in step 10300 = 5.073446273803711
# I dont know
#      [LOSS] Loss in step 10320 = 5.5521559715271
#      [LOSS] Loss in step 10340 = 4.381199836730957
#      [LOSS] Loss in step 10360 = 3.2787861824035645
#      [LOSS] Loss in step 10380 = 3.098935842514038
#      [LOSS] Loss in step 10400 = 2.669741630554199
# I dont know
#      [LOSS] Loss in step 10420 = 5.89619779586792
#      [LOSS] Loss in step 10440 = 5.470029354095459
#      [LOSS] Loss in step 10460 = 6.807681083679199
#      [LOSS] Loss in step 10480 = 6.351853847503662
#      [LOSS] Loss in step 10500 = 7.027310371398926
# I dont
#      [LOSS] Loss in step 10520 = 5.017411708831787
#      [LOSS] Loss in step 10540 = 2.4214253425598145
#      [LOSS] Loss in step 10560 = 4.132730484008789
#      [LOSS] Loss in step 10580 = 7.414742469787598
#      [LOSS] Loss in step 10600 = 6.529705047607422
# I you
#      [LOSS] Loss in step 10620 = 5.631952285766602
#      [LOSS] Loss in step 10640 = 4.942941188812256
#      [LOSS] Loss in step 10660 = 5.27013635635376
#      [LOSS] Loss in step 10680 = 4.8203229904174805
#      [LOSS] Loss in step 10700 = 6.9619832038879395
# I you
#      [LOSS] Loss in step 10720 = 5.245491981506348
#      [LOSS] Loss in step 10740 = 2.844855785369873
#      [LOSS] Loss in step 10760 = 4.000422954559326
#      [LOSS] Loss in step 10780 = 7.8972039222717285
#      [LOSS] Loss in step 10800 = 5.955049514770508
# I know I know
#      [LOSS] Loss in step 10820 = 4.231069087982178
#      [LOSS] Loss in step 10840 = 4.817893028259277
#      [LOSS] Loss in step 10860 = 5.19679069519043
#      [LOSS] Loss in step 10880 = 5.072206020355225
#      [LOSS] Loss in step 10900 = 6.861473083496094
# I
#      [LOSS] Loss in step 10920 = 5.854986667633057
#      [LOSS] Loss in step 10940 = 3.9461569786071777
#      [LOSS] Loss in step 10960 = 3.6810061931610107
#      [LOSS] Loss in step 10980 = 6.38935661315918
#      [LOSS] Loss in step 11000 = 2.3832852840423584
# I
#      [LOSS] Loss in step 11020 = 6.455653190612793
#      [LOSS] Loss in step 11040 = 5.015491008758545
#      [LOSS] Loss in step 11060 = 6.378500938415527
#      [LOSS] Loss in step 11080 = 5.588372230529785
#      [LOSS] Loss in step 11100 = 4.445748329162598
# I dont know
#      [LOSS] Loss in step 11120 = 6.591641426086426
#      [LOSS] Loss in step 11140 = 6.984914302825928
#      [LOSS] Loss in step 11160 = 5.901109218597412
#      [LOSS] Loss in step 11180 = 4.2925543785095215
#      [LOSS] Loss in step 11200 = 3.9218101501464844
# I dont know
#      [LOSS] Loss in step 11220 = 5.488376140594482
#      [LOSS] Loss in step 11240 = 3.3892998695373535
#      [LOSS] Loss in step 11260 = 3.377258539199829
#      [LOSS] Loss in step 11280 = 3.2057414054870605
#      [LOSS] Loss in step 11300 = 4.110647678375244
# I
#      [LOSS] Loss in step 11320 = 5.79588508605957
#      [LOSS] Loss in step 11340 = 5.021472930908203
#      [LOSS] Loss in step 11360 = 4.913461685180664
#      [LOSS] Loss in step 11380 = 7.272406578063965
#      [LOSS] Loss in step 11400 = 4.544930458068848
# I
#      [LOSS] Loss in step 11420 = 6.063599586486816
#      [LOSS] Loss in step 11440 = 3.2623324394226074
#      [LOSS] Loss in step 11460 = 6.364469528198242
#      [LOSS] Loss in step 11480 = 4.746358394622803
#      [LOSS] Loss in step 11500 = 7.132232189178467
# I
#      [LOSS] Loss in step 11520 = 7.041226863861084
#      [LOSS] Loss in step 11540 = 7.919827461242676
#      [LOSS] Loss in step 11560 = 4.818470001220703
#      [LOSS] Loss in step 11580 = 4.771398544311523
#      [LOSS] Loss in step 11600 = 4.3187761306762695
# I
#      [LOSS] Loss in step 11620 = 3.8868157863616943
#      [LOSS] Loss in step 11640 = 6.993494510650635
#      [LOSS] Loss in step 11660 = 6.597952842712402
#      [LOSS] Loss in step 11680 = 5.127401351928711
#      [LOSS] Loss in step 11700 = 1.9333386421203613
# I I I cant the one
#      [LOSS] Loss in step 11720 = 6.621463298797607
#      [LOSS] Loss in step 11740 = 6.6237287521362305
#      [LOSS] Loss in step 11760 = 4.275160789489746
#      [LOSS] Loss in step 11780 = 9.264054298400879
#      [LOSS] Loss in step 11800 = 5.2091827392578125
# I
#      [LOSS] Loss in step 11820 = 5.656073093414307
#      [LOSS] Loss in step 11840 = 4.243112087249756
#      [LOSS] Loss in step 11860 = 3.203385353088379
#      [LOSS] Loss in step 11880 = 7.785987854003906
#      [LOSS] Loss in step 11900 = 8.16226577758789
# I dont
#      [LOSS] Loss in step 11920 = 8.541651725769043
#      [LOSS] Loss in step 11940 = 6.206416130065918
#      [LOSS] Loss in step 11960 = 8.107049942016602
#      [LOSS] Loss in step 11980 = 5.672924995422363
#      [LOSS] Loss in step 12000 = 6.444715976715088
# I I
#      [LOSS] Loss in step 12020 = 2.3585612773895264
#      [LOSS] Loss in step 12040 = 5.281185626983643
#      [LOSS] Loss in step 12060 = 5.951723098754883
#      [LOSS] Loss in step 12080 = 3.596949338912964
#      [LOSS] Loss in step 12100 = 5.822975158691406
# I
#      [LOSS] Loss in step 12120 = 6.060449600219727
#      [LOSS] Loss in step 12140 = 4.942334175109863
#      [LOSS] Loss in step 12160 = 4.63557243347168
#      [LOSS] Loss in step 12180 = 7.147996425628662
#      [LOSS] Loss in step 12200 = 4.869424343109131
# I I
#      [LOSS] Loss in step 12220 = 4.876857280731201
#      [LOSS] Loss in step 12240 = 5.342350006103516
#      [LOSS] Loss in step 12260 = 6.52604866027832
#      [LOSS] Loss in step 12280 = 7.1470136642456055
#      [LOSS] Loss in step 12300 = 6.4693284034729
# I I
#      [LOSS] Loss in step 12320 = 4.9156413078308105
#      [LOSS] Loss in step 12340 = 5.831203460693359
#      [LOSS] Loss in step 12360 = 4.292911052703857
#      [LOSS] Loss in step 12380 = 4.056842803955078
#      [LOSS] Loss in step 12400 = 5.378568649291992
# I
#      [LOSS] Loss in step 12420 = 8.033076286315918
#      [LOSS] Loss in step 12440 = 4.986536026000977
#      [LOSS] Loss in step 12460 = 5.088407039642334
#      [LOSS] Loss in step 12480 = 8.00177001953125
#      [LOSS] Loss in step 12500 = 4.282571315765381
# I I
#      [LOSS] Loss in step 12520 = 6.210982799530029
#      [LOSS] Loss in step 12540 = 5.446220397949219
#      [LOSS] Loss in step 12560 = 7.556844234466553
#      [LOSS] Loss in step 12580 = 2.5767669677734375
#      [LOSS] Loss in step 12600 = 6.824685096740723
# I I think
#      [LOSS] Loss in step 12620 = 4.301599025726318
#      [LOSS] Loss in step 12640 = 2.9768197536468506
#      [LOSS] Loss in step 12660 = 5.661696434020996
#      [LOSS] Loss in step 12680 = 7.162041664123535
#      [LOSS] Loss in step 12700 = 5.958234786987305
# I know I know
#      [LOSS] Loss in step 12720 = 5.210968971252441
#      [LOSS] Loss in step 12740 = 3.707960367202759
#      [LOSS] Loss in step 12760 = 5.0974602699279785
#      [LOSS] Loss in step 12780 = 3.4833686351776123
#      [LOSS] Loss in step 12800 = 4.854833126068115
# I I
#      [LOSS] Loss in step 12820 = 7.8605499267578125
#      [LOSS] Loss in step 12840 = 4.687572002410889
#      [LOSS] Loss in step 12860 = 6.185179710388184
#      [LOSS] Loss in step 12880 = 6.195382118225098
#      [LOSS] Loss in step 12900 = 2.773343324661255
# I
#      [LOSS] Loss in step 12920 = 4.7755937576293945
#      [LOSS] Loss in step 12940 = 7.088672637939453
#      [LOSS] Loss in step 12960 = 3.1711814403533936
#      [LOSS] Loss in step 12980 = 5.9332709312438965
#      [LOSS] Loss in step 13000 = 6.184998989105225
# I think I dont know
#      [LOSS] Loss in step 13020 = 5.868764877319336
#      [LOSS] Loss in step 13040 = 6.847747802734375
#      [LOSS] Loss in step 13060 = 4.527021884918213
#      [LOSS] Loss in step 13080 = 7.521243095397949
#      [LOSS] Loss in step 13100 = 7.277990818023682
# I know
#      [LOSS] Loss in step 13120 = 4.201664447784424
#      [LOSS] Loss in step 13140 = 5.218780517578125
#      [LOSS] Loss in step 13160 = 6.567617416381836
#      [LOSS] Loss in step 13180 = 4.024050712585449
#      [LOSS] Loss in step 13200 = 4.973156452178955
# I
#      [LOSS] Loss in step 13220 = 5.415293216705322
#      [LOSS] Loss in step 13240 = 4.199636459350586
#      [LOSS] Loss in step 13260 = 3.6692113876342773
#      [LOSS] Loss in step 13280 = 4.520238876342773
#      [LOSS] Loss in step 13300 = 2.6050100326538086
# I just
#      [LOSS] Loss in step 13320 = 8.00295639038086
#      [LOSS] Loss in step 13340 = 6.775668144226074
#      [LOSS] Loss in step 13360 = 5.903799533843994
#      [LOSS] Loss in step 13380 = 1.704862117767334
#      [LOSS] Loss in step 13400 = 4.0428667068481445
# it
#      [LOSS] Loss in step 13420 = 1.7496169805526733
#      [LOSS] Loss in step 13440 = 2.09381365776062
#      [LOSS] Loss in step 13460 = 4.822524547576904
#      [LOSS] Loss in step 13480 = 4.519578456878662
#      [LOSS] Loss in step 13500 = 6.320207118988037
# what I was the door
#      [LOSS] Loss in step 13520 = 5.352174758911133
#      [LOSS] Loss in step 13540 = 2.055418014526367
#      [LOSS] Loss in step 13560 = 6.04519510269165
#      [LOSS] Loss in step 13580 = 6.678272247314453
#      [LOSS] Loss in step 13600 = 5.285073757171631
# I I
#      [LOSS] Loss in step 13620 = 3.6242527961730957
#      [LOSS] Loss in step 13640 = 5.321180820465088
#      [LOSS] Loss in step 13660 = 2.925743818283081
#      [LOSS] Loss in step 13680 = 7.871727466583252
#      [LOSS] Loss in step 13700 = 4.584352493286133
# I I
#      [LOSS] Loss in step 13720 = 7.9237823486328125
#      [LOSS] Loss in step 13740 = 2.1244120597839355
#      [LOSS] Loss in step 13760 = 4.475300312042236
#      [LOSS] Loss in step 13780 = 2.0584211349487305
#      [LOSS] Loss in step 13800 = 4.8906097412109375
# I I
#      [LOSS] Loss in step 13820 = 3.1256678104400635
#      [LOSS] Loss in step 13840 = 6.181844234466553
#      [LOSS] Loss in step 13860 = 5.999454021453857
#      [LOSS] Loss in step 13880 = 3.5390026569366455
#      [LOSS] Loss in step 13900 = 5.559459209442139
# I I
#      [LOSS] Loss in step 13920 = 5.674440860748291
#      [LOSS] Loss in step 13940 = 3.9895761013031006
#      [LOSS] Loss in step 13960 = 2.340102434158325
#      [LOSS] Loss in step 13980 = 6.104185104370117
#      [LOSS] Loss in step 14000 = 4.014156341552734
# I
#      [LOSS] Loss in step 14020 = 6.051716327667236
#      [LOSS] Loss in step 14040 = 5.634839057922363
#      [LOSS] Loss in step 14060 = 6.4542155265808105
#      [LOSS] Loss in step 14080 = 3.501810073852539
#      [LOSS] Loss in step 14100 = 5.450072288513184
# I
#      [LOSS] Loss in step 14120 = 4.753027439117432
#      [LOSS] Loss in step 14140 = 7.65545654296875
#      [LOSS] Loss in step 14160 = 3.2653586864471436
#      [LOSS] Loss in step 14180 = 4.574093341827393
#      [LOSS] Loss in step 14200 = 3.901750087738037
# I
#      [LOSS] Loss in step 14220 = 6.894379615783691
#      [LOSS] Loss in step 14240 = 3.805248260498047
#      [LOSS] Loss in step 14260 = 5.3790764808654785
#      [LOSS] Loss in step 14280 = 5.803619861602783
#      [LOSS] Loss in step 14300 = 2.5379817485809326
# I
#      [LOSS] Loss in step 14320 = 5.065097808837891
#      [LOSS] Loss in step 14340 = 6.30171012878418
#      [LOSS] Loss in step 14360 = 4.465697765350342
#      [LOSS] Loss in step 14380 = 7.105849742889404
#      [LOSS] Loss in step 14400 = 2.1439390182495117
# I
#      [LOSS] Loss in step 14420 = 8.583319664001465
#      [LOSS] Loss in step 14440 = 4.091249942779541
#      [LOSS] Loss in step 14460 = 5.4841461181640625
#      [LOSS] Loss in step 14480 = 7.131736755371094
#      [LOSS] Loss in step 14500 = 6.009483337402344
# I
#      [LOSS] Loss in step 14520 = 11.32228946685791
#      [LOSS] Loss in step 14540 = 7.138172626495361
#      [LOSS] Loss in step 14560 = 4.086604118347168
#      [LOSS] Loss in step 14580 = 5.331761360168457
#      [LOSS] Loss in step 14600 = 7.280149459838867
# I I
#      [LOSS] Loss in step 14620 = 4.550327301025391
#      [LOSS] Loss in step 14640 = 6.709845066070557
#      [LOSS] Loss in step 14660 = 6.234565258026123
#      [LOSS] Loss in step 14680 = 4.610730171203613
#      [LOSS] Loss in step 14700 = 3.141206741333008
# I I
#      [LOSS] Loss in step 14720 = 5.430408477783203
#      [LOSS] Loss in step 14740 = 7.567315578460693
#      [LOSS] Loss in step 14760 = 7.158716678619385
#      [LOSS] Loss in step 14780 = 5.851175308227539
#      [LOSS] Loss in step 14800 = 5.510350704193115
# I I
#      [LOSS] Loss in step 14820 = 5.418463230133057
#      [LOSS] Loss in step 14840 = 5.682299613952637
#      [LOSS] Loss in step 14860 = 7.33324670791626
#      [LOSS] Loss in step 14880 = 7.217495441436768
#      [LOSS] Loss in step 14900 = 5.298532009124756
# I
#      [LOSS] Loss in step 14920 = 2.5829036235809326
#      [LOSS] Loss in step 14940 = 1.765592336654663
#      [LOSS] Loss in step 14960 = 7.842457294464111
#      [LOSS] Loss in step 14980 = 3.0160999298095703
#      [LOSS] Loss in step 15000 = 6.523297309875488
# I
#      [LOSS] Loss in step 15020 = 6.148281097412109
#      [LOSS] Loss in step 15040 = 6.621315002441406
#      [LOSS] Loss in step 15060 = 4.630460739135742
#      [LOSS] Loss in step 15080 = 4.589733600616455
#      [LOSS] Loss in step 15100 = 6.755673885345459
# I dont know
#      [LOSS] Loss in step 15120 = 6.303308010101318
#      [LOSS] Loss in step 15140 = 5.121275901794434
#      [LOSS] Loss in step 15160 = 4.884208679199219
#      [LOSS] Loss in step 15180 = 7.146614074707031
#      [LOSS] Loss in step 15200 = 7.239748001098633
# I have to be a good
#      [LOSS] Loss in step 15220 = 3.184701919555664
#      [LOSS] Loss in step 15240 = 4.832394123077393
#      [LOSS] Loss in step 15260 = 3.282766342163086
#      [LOSS] Loss in step 15280 = 6.220973968505859
#      [LOSS] Loss in step 15300 = 2.620086669921875
# I know
#      [LOSS] Loss in step 15320 = 4.528968811035156
#      [LOSS] Loss in step 15340 = 3.970309019088745
#      [LOSS] Loss in step 15360 = 8.257168769836426
#      [LOSS] Loss in step 15380 = 2.6649134159088135
#      [LOSS] Loss in step 15400 = 2.3144028186798096
# I was a way
#      [LOSS] Loss in step 15420 = 4.609678268432617
#      [LOSS] Loss in step 15440 = 3.4307267665863037
#      [LOSS] Loss in step 15460 = 5.76523494720459
#      [LOSS] Loss in step 15480 = 1.8459935188293457
#      [LOSS] Loss in step 15500 = 5.24182653427124
# I
#      [LOSS] Loss in step 15520 = 7.419924736022949
#      [LOSS] Loss in step 15540 = 5.385854244232178
#      [LOSS] Loss in step 15560 = 8.922675132751465
#      [LOSS] Loss in step 15580 = 6.4128098487854
#      [LOSS] Loss in step 15600 = 5.177940845489502
# I you
#      [LOSS] Loss in step 15620 = 5.850889205932617
#      [LOSS] Loss in step 15640 = 5.730599880218506
#      [LOSS] Loss in step 15660 = 5.562164306640625
#      [LOSS] Loss in step 15680 = 8.67845630645752
#      [LOSS] Loss in step 15700 = 6.6591105461120605
# I I
#      [LOSS] Loss in step 15720 = 5.830960750579834
#      [LOSS] Loss in step 15740 = 5.554133892059326
#      [LOSS] Loss in step 15760 = 2.0670461654663086
#      [LOSS] Loss in step 15780 = 2.2488861083984375
#      [LOSS] Loss in step 15800 = 2.7270548343658447
# I you I cant be a good
#      [LOSS] Loss in step 15820 = 10.438874244689941
#      [LOSS] Loss in step 15840 = 4.094839096069336
#      [LOSS] Loss in step 15860 = 6.44285249710083
#      [LOSS] Loss in step 15880 = 4.581938743591309
#      [LOSS] Loss in step 15900 = 4.4385085105896
# I I
#      [LOSS] Loss in step 15920 = 7.624980926513672
#      [LOSS] Loss in step 15940 = 5.908481597900391
#      [LOSS] Loss in step 15960 = 5.935451984405518
#      [LOSS] Loss in step 15980 = 6.045839786529541
#      [LOSS] Loss in step 16000 = 4.154232978820801
# I know you
#      [LOSS] Loss in step 16020 = 5.505602836608887
#      [LOSS] Loss in step 16040 = 6.9181742668151855
#      [LOSS] Loss in step 16060 = 4.068921089172363
#      [LOSS] Loss in step 16080 = 5.270773410797119
#      [LOSS] Loss in step 16100 = 4.267161846160889
# I know you
#      [LOSS] Loss in step 16120 = 2.8018641471862793
#      [LOSS] Loss in step 16140 = 2.7223868370056152
#      [LOSS] Loss in step 16160 = 7.749941825866699
#      [LOSS] Loss in step 16180 = 6.158292770385742
#      [LOSS] Loss in step 16200 = 5.784578800201416
# I know
#      [LOSS] Loss in step 16220 = 3.873666286468506
#      [LOSS] Loss in step 16240 = 7.0008978843688965
#      [LOSS] Loss in step 16260 = 5.090750694274902
#      [LOSS] Loss in step 16280 = 6.326554298400879
#      [LOSS] Loss in step 16300 = 5.905999183654785
# I know
#      [LOSS] Loss in step 16320 = 5.88267707824707
#      [LOSS] Loss in step 16340 = 7.137221336364746
#      [LOSS] Loss in step 16360 = 3.206456184387207
#      [LOSS] Loss in step 16380 = 7.520359039306641
#      [LOSS] Loss in step 16400 = 4.859211444854736
# I know
#      [LOSS] Loss in step 16420 = 3.2584025859832764
#      [LOSS] Loss in step 16440 = 6.535641193389893
#      [LOSS] Loss in step 16460 = 7.224168300628662
#      [LOSS] Loss in step 16480 = 5.387643337249756
#      [LOSS] Loss in step 16500 = 3.510596752166748
# I
#      [LOSS] Loss in step 16520 = 7.211501598358154
#      [LOSS] Loss in step 16540 = 3.359882354736328
#      [LOSS] Loss in step 16560 = 5.309469699859619
#      [LOSS] Loss in step 16580 = 7.074782848358154
#      [LOSS] Loss in step 16600 = 5.407354354858398
# I
#      [LOSS] Loss in step 16620 = 6.542932987213135
#      [LOSS] Loss in step 16640 = 5.971617698669434
#      [LOSS] Loss in step 16660 = 4.387139320373535
#      [LOSS] Loss in step 16680 = 5.0173115730285645
#      [LOSS] Loss in step 16700 = 6.141820907592773
# I
#      [LOSS] Loss in step 16720 = 7.589262962341309
#      [LOSS] Loss in step 16740 = 5.909087657928467
#      [LOSS] Loss in step 16760 = 4.486513137817383
#      [LOSS] Loss in step 16780 = 7.572535991668701
#      [LOSS] Loss in step 16800 = 6.746180534362793
# I
#      [LOSS] Loss in step 16820 = 5.4061455726623535
#      [LOSS] Loss in step 16840 = 7.849222183227539
#      [LOSS] Loss in step 16860 = 4.554013729095459
#      [LOSS] Loss in step 16880 = 5.395461559295654
#      [LOSS] Loss in step 16900 = 4.163665771484375
# I
#      [LOSS] Loss in step 16920 = 5.368831634521484
#      [LOSS] Loss in step 16940 = 3.9435698986053467
#      [LOSS] Loss in step 16960 = 5.072020053863525
#      [LOSS] Loss in step 16980 = 4.685348033905029
#      [LOSS] Loss in step 17000 = 4.46823263168335
# I
#      [LOSS] Loss in step 17020 = 6.19193696975708
#      [LOSS] Loss in step 17040 = 2.9364075660705566
#      [LOSS] Loss in step 17060 = 6.8772711753845215
#      [LOSS] Loss in step 17080 = 6.8381853103637695
#      [LOSS] Loss in step 17100 = 3.324366331100464
# I
#      [LOSS] Loss in step 17120 = 6.231191158294678
#      [LOSS] Loss in step 17140 = 4.648804664611816
#      [LOSS] Loss in step 17160 = 5.679244518280029
#      [LOSS] Loss in step 17180 = 5.989832401275635
#      [LOSS] Loss in step 17200 = 6.952202320098877
# I
#      [LOSS] Loss in step 17220 = 4.486505031585693
#      [LOSS] Loss in step 17240 = 8.519452095031738
#      [LOSS] Loss in step 17260 = 11.056478500366211
#      [LOSS] Loss in step 17280 = 3.565890073776245
#      [LOSS] Loss in step 17300 = 4.059711933135986
# I
#      [LOSS] Loss in step 17320 = 6.730887413024902
#      [LOSS] Loss in step 17340 = 5.399744987487793
#      [LOSS] Loss in step 17360 = 4.8938798904418945
#      [LOSS] Loss in step 17380 = 6.727038383483887
#      [LOSS] Loss in step 17400 = 3.136381149291992
# I
#      [LOSS] Loss in step 17420 = 4.3886213302612305
#      [LOSS] Loss in step 17440 = 5.8792595863342285
#      [LOSS] Loss in step 17460 = 7.268653392791748
#      [LOSS] Loss in step 17480 = 2.2822461128234863
#      [LOSS] Loss in step 17500 = 4.651268005371094
# I was a good little
#      [LOSS] Loss in step 17520 = 4.655144691467285
#      [LOSS] Loss in step 17540 = 4.693853378295898
#      [LOSS] Loss in step 17560 = 3.685779094696045
#      [LOSS] Loss in step 17580 = 7.775257110595703
#      [LOSS] Loss in step 17600 = 3.999826431274414
# I
#      [LOSS] Loss in step 17620 = 6.130648136138916
#      [LOSS] Loss in step 17640 = 6.889646053314209
#      [LOSS] Loss in step 17660 = 6.164255142211914
#      [LOSS] Loss in step 17680 = 5.8964691162109375
#      [LOSS] Loss in step 17700 = 5.825316905975342
# I think I just want to do I
#      [LOSS] Loss in step 17720 = 3.887148380279541
#      [LOSS] Loss in step 17740 = 6.722268104553223
#      [LOSS] Loss in step 17760 = 7.8341522216796875
#      [LOSS] Loss in step 17780 = 4.091414928436279
#      [LOSS] Loss in step 17800 = 5.5321269035339355
# I think
#      [LOSS] Loss in step 17820 = 8.394416809082031
#      [LOSS] Loss in step 17840 = 6.2801337242126465
#      [LOSS] Loss in step 17860 = 7.617475509643555
#      [LOSS] Loss in step 17880 = 6.0693206787109375
#      [LOSS] Loss in step 17900 = 6.080256938934326
# I
#      [LOSS] Loss in step 17920 = 5.495335578918457
#      [LOSS] Loss in step 17940 = 5.294064521789551
#      [LOSS] Loss in step 17960 = 4.0175580978393555
#      [LOSS] Loss in step 17980 = 6.057828426361084
#      [LOSS] Loss in step 18000 = 3.073897123336792
# I think
#      [LOSS] Loss in step 18020 = 6.425064563751221
#      [LOSS] Loss in step 18040 = 5.021801471710205
#      [LOSS] Loss in step 18060 = 7.0999836921691895
#      [LOSS] Loss in step 18080 = 4.897773265838623
#      [LOSS] Loss in step 18100 = 5.573462963104248
# I I
#      [LOSS] Loss in step 18120 = 8.184599876403809
#      [LOSS] Loss in step 18140 = 4.6093854904174805
#      [LOSS] Loss in step 18160 = 6.633033275604248
#      [LOSS] Loss in step 18180 = 6.479319095611572
#      [LOSS] Loss in step 18200 = 6.922451972961426
# been
#      [LOSS] Loss in step 18220 = 5.451826095581055
#      [LOSS] Loss in step 18240 = 5.233887672424316
#      [LOSS] Loss in step 18260 = 5.998146057128906
#      [LOSS] Loss in step 18280 = 5.941999912261963
#      [LOSS] Loss in step 18300 = 6.528822898864746
# I think I could be a good
#      [LOSS] Loss in step 18320 = 3.661961317062378
#      [LOSS] Loss in step 18340 = 5.784631729125977
#      [LOSS] Loss in step 18360 = 4.916208267211914
#      [LOSS] Loss in step 18380 = 6.0173749923706055
# ...
#      [LOSS] Loss in step 28780 = 5.102627754211426
#      [LOSS] Loss in step 28800 = 6.921854496002197
# I
#      [LOSS] Loss in step 28820 = 2.605530023574829
#      [LOSS] Loss in step 28840 = 3.8596982955932617
#      [LOSS] Loss in step 28860 = 5.943253993988037
#      [LOSS] Loss in step 28880 = 3.0912654399871826
#      [LOSS] Loss in step 28900 = 8.619694709777832
# I could
#      [LOSS] Loss in step 28920 = 3.766099452972412
#      [LOSS] Loss in step 28940 = 5.994230270385742
#      [LOSS] Loss in step 28960 = 5.257199764251709
#      [LOSS] Loss in step 28980 = 4.676340579986572
#      [LOSS] Loss in step 29000 = 5.830048561096191
# I
#      [LOSS] Loss in step 29020 = 6.7402143478393555
#      [LOSS] Loss in step 29040 = 5.900407314300537
#      [LOSS] Loss in step 29060 = 2.3844456672668457
#      [LOSS] Loss in step 29080 = 7.044301509857178
#      [LOSS] Loss in step 29100 = 6.283083438873291
#
#      [LOSS] Loss in step 29120 = 3.3536951541900635
#      [LOSS] Loss in step 29140 = 4.310571670532227
#      [LOSS] Loss in step 29160 = 3.0560224056243896
#      [LOSS] Loss in step 29180 = 5.435654640197754
#      [LOSS] Loss in step 29200 = 6.119081974029541
#
#      [LOSS] Loss in step 29220 = 3.6981825828552246
#      [LOSS] Loss in step 29240 = 6.749098300933838
#      [LOSS] Loss in step 29260 = 7.962912082672119
#      [LOSS] Loss in step 29280 = 5.614626407623291
#      [LOSS] Loss in step 29300 = 5.1192240715026855
#
#      [LOSS] Loss in step 29320 = 4.0630598068237305
#      [LOSS] Loss in step 29340 = 5.024278163909912
#      [LOSS] Loss in step 29360 = 3.7579548358917236
#      [LOSS] Loss in step 29380 = 5.742377758026123
#      [LOSS] Loss in step 29400 = 4.039792060852051
#
#      [LOSS] Loss in step 29420 = 7.535466194152832
#      [LOSS] Loss in step 29440 = 6.233741283416748
#      [LOSS] Loss in step 29460 = 8.356685638427734
#      [LOSS] Loss in step 29480 = 7.1374030113220215
#      [LOSS] Loss in step 29500 = 5.550937652587891
# I
#      [LOSS] Loss in step 29520 = 6.372507572174072
#      [LOSS] Loss in step 29540 = 3.807467222213745
#      [LOSS] Loss in step 29560 = 5.302745819091797
#      [LOSS] Loss in step 29580 = 4.685542106628418
#      [LOSS] Loss in step 29600 = 8.451929092407227
#
#      [LOSS] Loss in step 29620 = 5.213422775268555
#      [LOSS] Loss in step 29640 = 4.77284049987793
#      [LOSS] Loss in step 29660 = 3.9987921714782715
#      [LOSS] Loss in step 29680 = 7.256990909576416
#      [LOSS] Loss in step 29700 = 5.483157157897949
# I
#      [LOSS] Loss in step 29720 = 8.33991813659668
#      [LOSS] Loss in step 29740 = 6.210955619812012
#      [LOSS] Loss in step 29760 = 6.9945502281188965
#      [LOSS] Loss in step 29780 = 5.522232532501221
#      [LOSS] Loss in step 29800 = 4.776232719421387
# ruin
#      [LOSS] Loss in step 29820 = 5.667502403259277
#      [LOSS] Loss in step 29840 = 7.095047473907471
#      [LOSS] Loss in step 29860 = 5.107585430145264
#      [LOSS] Loss in step 29880 = 5.9230475425720215
#      [LOSS] Loss in step 29900 = 5.0574212074279785
#
#      [LOSS] Loss in step 29920 = 6.89411735534668
#      [LOSS] Loss in step 29940 = 4.369132041931152
#      [LOSS] Loss in step 29960 = 4.613377094268799
#      [LOSS] Loss in step 29980 = 6.814758777618408
#      [LOSS] Loss in step 30000 = 8.381719589233398
# ruin
#      [LOSS] Loss in step 30020 = 6.960927963256836
#      [LOSS] Loss in step 30040 = 5.768820762634277
#      [LOSS] Loss in step 30060 = 5.5560784339904785
#      [LOSS] Loss in step 30080 = 6.398704528808594
#      [LOSS] Loss in step 30100 = 3.4686970710754395
# I
#      [LOSS] Loss in step 30120 = 8.10875415802002
#      [LOSS] Loss in step 30140 = 6.773585319519043
#      [LOSS] Loss in step 30160 = 3.0411558151245117
#      [LOSS] Loss in step 30180 = 6.475651741027832
#      [LOSS] Loss in step 30200 = 6.475855350494385
#
#      [LOSS] Loss in step 30220 = 3.790780782699585
#      [LOSS] Loss in step 30240 = 5.618268013000488
#      [LOSS] Loss in step 30260 = 4.1114726066589355
#      [LOSS] Loss in step 30280 = 7.140013217926025
#      [LOSS] Loss in step 30300 = 6.658494472503662
# be
#      [LOSS] Loss in step 30320 = 6.533573150634766
#      [LOSS] Loss in step 30340 = 5.449929714202881
#      [LOSS] Loss in step 30360 = 3.2926557064056396
#      [LOSS] Loss in step 30380 = 4.001455307006836
#      [LOSS] Loss in step 30400 = 4.928839206695557
# I
#      [LOSS] Loss in step 30420 = 5.653934001922607
#      [LOSS] Loss in step 30440 = 9.898340225219727
#      [LOSS] Loss in step 30460 = 6.037883758544922
#      [LOSS] Loss in step 30480 = 5.916839122772217
#      [LOSS] Loss in step 30500 = 4.756202697753906
# I
#      [LOSS] Loss in step 30520 = 3.6154627799987793
#      [LOSS] Loss in step 30540 = 3.0381059646606445
#      [LOSS] Loss in step 30560 = 7.743797302246094
#      [LOSS] Loss in step 30580 = 6.674674987792969
#      [LOSS] Loss in step 30600 = 7.327772617340088
# here
#      [LOSS] Loss in step 30620 = 7.701016902923584
#      [LOSS] Loss in step 30640 = 6.157899856567383
#      [LOSS] Loss in step 30660 = 6.4040327072143555
#      [LOSS] Loss in step 30680 = 4.414402484893799
#      [LOSS] Loss in step 30700 = 6.844335079193115
# I
#      [LOSS] Loss in step 30720 = 6.774959087371826
#      [LOSS] Loss in step 30740 = 5.739758491516113
#      [LOSS] Loss in step 30760 = 5.41087532043457
#      [LOSS] Loss in step 30780 = 6.08164644241333
#      [LOSS] Loss in step 30800 = 6.452669143676758
# I
#      [LOSS] Loss in step 30820 = 4.551472187042236
#      [LOSS] Loss in step 30840 = 6.321530342102051
#      [LOSS] Loss in step 30860 = 8.029115676879883
#      [LOSS] Loss in step 30880 = 4.459249019622803
#      [LOSS] Loss in step 30900 = 7.568841457366943
# I
#      [LOSS] Loss in step 30920 = 3.349228858947754
#      [LOSS] Loss in step 30940 = 7.782898902893066
#      [LOSS] Loss in step 30960 = 4.262324810028076
#      [LOSS] Loss in step 30980 = 3.8781368732452393
#      [LOSS] Loss in step 31000 = 6.5118255615234375
# I want to be
#      [LOSS] Loss in step 31020 = 2.687558889389038
#      [LOSS] Loss in step 31040 = 6.084558963775635
#      [LOSS] Loss in step 31060 = 5.677859783172607
#      [LOSS] Loss in step 31080 = 7.441269397735596
#      [LOSS] Loss in step 31100 = 1.579520583152771
#
#      [LOSS] Loss in step 31120 = 6.293674945831299
#      [LOSS] Loss in step 31140 = 6.412115573883057
#      [LOSS] Loss in step 31160 = 1.6980977058410645
#      [LOSS] Loss in step 31180 = 6.015388488769531
#      [LOSS] Loss in step 31200 = 4.932635307312012
# I
#      [LOSS] Loss in step 31220 = 6.418069839477539
#      [LOSS] Loss in step 31240 = 3.351975917816162
#      [LOSS] Loss in step 31260 = 4.393365383148193
#      [LOSS] Loss in step 31280 = 4.247647285461426
#      [LOSS] Loss in step 31300 = 3.9077656269073486
# I
#      [LOSS] Loss in step 31320 = 4.879775047302246
#      [LOSS] Loss in step 31340 = 6.923733234405518
#      [LOSS] Loss in step 31360 = 4.486260414123535
#      [LOSS] Loss in step 31380 = 6.358956813812256
#      [LOSS] Loss in step 31400 = 3.035954713821411
# me
#      [LOSS] Loss in step 31420 = 10.30019474029541
#      [LOSS] Loss in step 31440 = 4.945909023284912
#      [LOSS] Loss in step 31460 = 5.677437782287598
#      [LOSS] Loss in step 31480 = 6.603010177612305
#      [LOSS] Loss in step 31500 = 6.2094855308532715
# me I want
#      [LOSS] Loss in step 31520 = 8.315081596374512
#      [LOSS] Loss in step 31540 = 7.298351764678955
#      [LOSS] Loss in step 31560 = 6.066452980041504
#      [LOSS] Loss in step 31580 = 7.743533611297607
#      [LOSS] Loss in step 31600 = 5.096433162689209
# me
#      [LOSS] Loss in step 31620 = 7.434685230255127
#      [LOSS] Loss in step 31640 = 5.536669731140137
#      [LOSS] Loss in step 31660 = 5.10887336730957
#      [LOSS] Loss in step 31680 = 5.166942596435547
#      [LOSS] Loss in step 31700 = 2.8798797130584717
# I
#      [LOSS] Loss in step 31720 = 3.3979101181030273
#      [LOSS] Loss in step 31740 = 4.274207592010498
#      [LOSS] Loss in step 31760 = 7.958456993103027
#      [LOSS] Loss in step 31780 = 7.260666370391846
#      [LOSS] Loss in step 31800 = 5.981354713439941
# I want to do
#      [LOSS] Loss in step 31820 = 6.314185619354248
#      [LOSS] Loss in step 31840 = 7.288593292236328
#      [LOSS] Loss in step 31860 = 3.5949504375457764
#      [LOSS] Loss in step 31880 = 5.360494613647461
#      [LOSS] Loss in step 31900 = 6.61800479888916
# of the large
#      [LOSS] Loss in step 31920 = 5.498623371124268
#      [LOSS] Loss in step 31940 = 4.37105131149292
#      [LOSS] Loss in step 31960 = 2.064560890197754
#      [LOSS] Loss in step 31980 = 5.0167646408081055
#      [LOSS] Loss in step 32000 = 5.211693286895752
# of the attractive
#      [LOSS] Loss in step 32020 = 3.984213352203369
#      [LOSS] Loss in step 32040 = 6.142405986785889
#      [LOSS] Loss in step 32060 = 2.7352442741394043
#      [LOSS] Loss in step 32080 = 3.1315784454345703
#      [LOSS] Loss in step 32100 = 7.074464321136475
# me
#      [LOSS] Loss in step 32120 = 2.9349594116210938
#      [LOSS] Loss in step 32140 = 5.117117404937744
#      [LOSS] Loss in step 32160 = 9.444628715515137
#      [LOSS] Loss in step 32180 = 7.374455451965332
#      [LOSS] Loss in step 32200 = 6.250122547149658
# I want to
#      [LOSS] Loss in step 32220 = 6.443944931030273
#      [LOSS] Loss in step 32240 = 8.3402099609375
#      [LOSS] Loss in step 32260 = 6.3080363273620605
#      [LOSS] Loss in step 32280 = 4.921412944793701
#      [LOSS] Loss in step 32300 = 2.791499614715576
# I want
#      [LOSS] Loss in step 32320 = 3.379138708114624
#      [LOSS] Loss in step 32340 = 3.8721954822540283
#      [LOSS] Loss in step 32360 = 4.086007118225098
#      [LOSS] Loss in step 32380 = 2.0665807723999023
#      [LOSS] Loss in step 32400 = 4.501946926116943
# me
#      [LOSS] Loss in step 32420 = 5.451967716217041
#      [LOSS] Loss in step 32440 = 3.012943744659424
#      [LOSS] Loss in step 32460 = 7.469962120056152
#      [LOSS] Loss in step 32480 = 3.80289888381958
#      [LOSS] Loss in step 32500 = 5.017323017120361
# I want to be attractive
#      [LOSS] Loss in step 32520 = 9.014513969421387
#      [LOSS] Loss in step 32540 = 6.8248467445373535
#      [LOSS] Loss in step 32560 = 3.3813862800598145
#      [LOSS] Loss in step 32580 = 4.41707706451416
#      [LOSS] Loss in step 32600 = 7.8595476150512695
# it
#      [LOSS] Loss in step 32620 = 5.8303046226501465
#      [LOSS] Loss in step 32640 = 6.338981628417969
#      [LOSS] Loss in step 32660 = 2.920485496520996
#      [LOSS] Loss in step 32680 = 4.469583034515381
#      [LOSS] Loss in step 32700 = 6.227446556091309
# I know
#      [LOSS] Loss in step 32720 = 5.947317600250244
#      [LOSS] Loss in step 32740 = 3.9953174591064453
#      [LOSS] Loss in step 32760 = 6.256920337677002
#      [LOSS] Loss in step 32780 = 5.276101589202881
#      [LOSS] Loss in step 32800 = 3.372906446456909
# me me
#      [LOSS] Loss in step 32820 = 6.2155938148498535
#      [LOSS] Loss in step 32840 = 4.7999091148376465
#      [LOSS] Loss in step 32860 = 5.106076717376709
#      [LOSS] Loss in step 32880 = 3.0340843200683594
#      [LOSS] Loss in step 32900 = 5.624701976776123
# me out
#      [LOSS] Loss in step 32920 = 3.6749179363250732
#      [LOSS] Loss in step 32940 = 2.9803855419158936
#      [LOSS] Loss in step 32960 = 6.147559642791748
#      [LOSS] Loss in step 32980 = 5.645472049713135
#      [LOSS] Loss in step 33000 = 8.019672393798828
# ex
#      [LOSS] Loss in step 33020 = 6.457765102386475
#      [LOSS] Loss in step 33040 = 7.013561725616455
#      [LOSS] Loss in step 33060 = 4.021271705627441
#      [LOSS] Loss in step 33080 = 5.125160217285156
#      [LOSS] Loss in step 33100 = 4.255281448364258
# me me
#      [LOSS] Loss in step 33120 = 7.687325954437256
#      [LOSS] Loss in step 33140 = 6.731636047363281
#      [LOSS] Loss in step 33160 = 8.037494659423828
#      [LOSS] Loss in step 33180 = 6.336871147155762
#      [LOSS] Loss in step 33200 = 8.98458480834961
# Buzz me
#      [LOSS] Loss in step 33220 = 3.2602078914642334
#      [LOSS] Loss in step 33240 = 5.1997971534729
#      [LOSS] Loss in step 33260 = 9.954261779785156
#      [LOSS] Loss in step 33280 = 2.4541847705841064
#      [LOSS] Loss in step 33300 = 5.765421390533447
# me me
#      [LOSS] Loss in step 33320 = 7.3798956871032715
#      [LOSS] Loss in step 33340 = 2.3122496604919434
#      [LOSS] Loss in step 33360 = 6.977138996124268
#      [LOSS] Loss in step 33380 = 4.3623270988464355
#      [LOSS] Loss in step 33400 = 7.747395038604736
# me
#      [LOSS] Loss in step 33420 = 7.630919933319092
#      [LOSS] Loss in step 33440 = 6.273787498474121
#      [LOSS] Loss in step 33460 = 3.49458384513855
#      [LOSS] Loss in step 33480 = 4.281267166137695
#      [LOSS] Loss in step 33500 = 6.1293511390686035
# me out
#      [LOSS] Loss in step 33520 = 6.176323890686035
#      [LOSS] Loss in step 33540 = 5.087188243865967
#      [LOSS] Loss in step 33560 = 5.25132942199707
#      [LOSS] Loss in step 33580 = 4.996055603027344
#      [LOSS] Loss in step 33600 = 6.612718105316162
# me me
#      [LOSS] Loss in step 33620 = 2.423778533935547
#      [LOSS] Loss in step 33640 = 2.9359958171844482
#      [LOSS] Loss in step 33660 = 6.9139533042907715
#      [LOSS] Loss in step 33680 = 8.604175567626953
#      [LOSS] Loss in step 33700 = 6.2285308837890625
# shut eyes eyes eyes eyes eyes eyes Roger
#      [LOSS] Loss in step 33720 = 6.054530143737793
#      [LOSS] Loss in step 33740 = 15.06401538848877
#      [LOSS] Loss in step 33760 = 5.170958518981934
#      [LOSS] Loss in step 33780 = 6.317060947418213
#      [LOSS] Loss in step 33800 = 5.699404239654541
# reasons exotic
#      [LOSS] Loss in step 33820 = 10.635211944580078
#      [LOSS] Loss in step 33840 = 3.9326062202453613
#      [LOSS] Loss in step 33860 = 5.245105266571045
#      [LOSS] Loss in step 33880 = 6.106507778167725
#      [LOSS] Loss in step 33900 = 5.6154351234436035
# me
#      [LOSS] Loss in step 33920 = 7.346092224121094
#      [LOSS] Loss in step 33940 = 4.854105472564697
#      [LOSS] Loss in step 33960 = 7.459724426269531
#      [LOSS] Loss in step 33980 = 1.8886289596557617
#      [LOSS] Loss in step 34000 = 4.50924825668335
# I I
#      [LOSS] Loss in step 34020 = 7.313601970672607
#      [LOSS] Loss in step 34040 = 13.971381187438965
#      [LOSS] Loss in step 34060 = 7.422535419464111
#      [LOSS] Loss in step 34080 = 5.094826698303223
#      [LOSS] Loss in step 34100 = 7.4966630935668945
# I
#      [LOSS] Loss in step 34120 = 2.8011927604675293
#      [LOSS] Loss in step 34140 = 3.7158353328704834
#      [LOSS] Loss in step 34160 = 9.049139976501465
#      [LOSS] Loss in step 34180 = 4.387038230895996
#      [LOSS] Loss in step 34200 = 6.711555480957031
# I I I I I I I I
#      [LOSS] Loss in step 34220 = 5.368611812591553
#      [LOSS] Loss in step 34240 = 6.812841415405273
#      [LOSS] Loss in step 34260 = 3.364557981491089
#      [LOSS] Loss in step 34280 = 13.531393051147461
#      [LOSS] Loss in step 34300 = 4.140687465667725
# I have been your
#      [LOSS] Loss in step 34320 = 6.917567729949951
#      [LOSS] Loss in step 34340 = 5.522925853729248
#      [LOSS] Loss in step 34360 = 5.345020771026611
#      [LOSS] Loss in step 34380 = 5.6911725997924805
#      [LOSS] Loss in step 34400 = 4.179708480834961
# I mean
#      [LOSS] Loss in step 34420 = 6.488921642303467
#      [LOSS] Loss in step 34440 = 3.0330090522766113
#      [LOSS] Loss in step 34460 = 4.428382873535156
#      [LOSS] Loss in step 34480 = 6.59511137008667
#      [LOSS] Loss in step 34500 = 1.8009151220321655
# I have to
#      [LOSS] Loss in step 34520 = 3.5122601985931396
#      [LOSS] Loss in step 34540 = 8.221508979797363
#      [LOSS] Loss in step 34560 = 4.45911169052124
#      [LOSS] Loss in step 34580 = 6.422239303588867
#      [LOSS] Loss in step 34600 = 5.117030143737793
# me
#      [LOSS] Loss in step 34620 = 4.695659637451172
#      [LOSS] Loss in step 34640 = 3.4901931285858154
#      [LOSS] Loss in step 34660 = 4.541416645050049
#      [LOSS] Loss in step 34680 = 5.51183557510376
#      [LOSS] Loss in step 34700 = 4.715375900268555
# me ends
#      [LOSS] Loss in step 34720 = 4.863629341125488
#      [LOSS] Loss in step 34740 = 8.760733604431152
#      [LOSS] Loss in step 34760 = 9.211078643798828
#      [LOSS] Loss in step 34780 = 6.586808681488037
#      [LOSS] Loss in step 34800 = 5.837442874908447
# me
#      [LOSS] Loss in step 34820 = 4.78757905960083
#      [LOSS] Loss in step 34840 = 3.7810161113739014

# %%
evaluate("I love you please")
# Out:
# I
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   # Remove the CWD from sys.path while we load stuff.
