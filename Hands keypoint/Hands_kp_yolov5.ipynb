# %%
# !git clone https://github.com/TheSun00000/hands_dataset/
# !git clone https://github.com/ultralytics/yolov5  # clone repo

# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# Setup complete. Using torch 1.7.0+cu101 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source /content/hands_dataset/data/images/train/150.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='/content/hands_dataset/data/images/train/150.jpg', update=False, view_img=False, weights=['yolov5s.pt'])
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079.75MB)
#
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 108MB/s]
#
# Fusing layers...
# Model Summary: 224 layers, 7266973 parameters, 0 gradients, 17.0 GFLOPS
# image 1/1 /content/hands_dataset/data/images/train/150.jpg: 384x640 2 persons, Done. (0.036s)
# Results saved to runs/detect/exp
# Done. (0.209s)

# %%
# !python3 train.py --img 640 --batch 1 --epochs 50 --data /content/hands_dataset/dataset.yaml --cfg ./models/yolov5l.yaml --weights yolov5l.pt --device 0\
    --noautoanchor
# Out:
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079.75MB)
#
#
# Namespace(adam=False, batch_size=1, bucket='', cache_images=False, cfg='./models/yolov5l.yaml', data='/content/hands_dataset/dataset.yaml', device='0', epochs=50, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[640, 640], local_rank=-1, log_artifacts=False, log_imgs=16, multi_scale=False, name='exp', noautoanchor=True, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp15', single_cls=False, sync_bn=False, total_batch_size=1, weights='yolov5l.pt', workers=8, world_size=1)
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# 2021-01-08 14:30:29.221175: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !python detect.py --weights runs/train/exp4/weights/best.pt --img 640 --conf 0.25 --source /content/hands_dataset/data/images/train/250.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='/content/hands_dataset/data/images/train/250.jpg', update=False, view_img=False, weights=['runs/train/exp4/weights/best.pt'])
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079.75MB)
#
#
# Fusing layers...
# Model Summary: 224 layers, 7107850 parameters, 0 gradients, 16.5 GFLOPS
# image 1/1 /content/hands_dataset/data/images/train/250.jpg: 384x640 Done. (0.010s)
# Results saved to runs/detect/exp5
# Done. (0.049s)

# %%
# !python detect.py --weights runs/train/exp15/weights/best.pt --img 640 --conf 0.25 --source /content/hands_dataset/data/images/train/255.jpg
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=640, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='/content/hands_dataset/data/images/train/255.jpg', update=False, view_img=False, weights=['runs/train/exp15/weights/best.pt'])
# Using torch 1.7.0+cu101 CUDA:0 (Tesla T4, 15079.75MB)
#
#
# Fusing layers...
# Model Summary: 392 layers, 46708266 parameters, 0 gradients, 114.4 GFLOPS
# image 1/1 /content/hands_dataset/data/images/train/255.jpg: 384x640 Done. (0.026s)
# Results saved to runs/detect/exp7
# Done. (0.085s)
